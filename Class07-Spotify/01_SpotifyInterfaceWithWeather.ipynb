# %%
import spotipy
import json
import webbrowser
import pandas as pd

# %%
import urllib.request
import spotipy.util as util

# %%
# copy and paste the url into your browser to see what data you are getting back
request = urllib.request.Request("https://weatherdbi.herokuapp.com/data/weather/toyoko")
response = urllib.request.urlopen(request)

# %%
weather = json.loads(response.read())

# %%
print(weather)
# Out:
# {'region': 'Tokyo, Japan', 'currentConditions': {'dayhour': 'Wednesday 11:00 PM', 'temp': {'c': 12, 'f': 53}, 'precip': '40%', 'humidity': '95%', 'wind': {'km': 14, 'mile': 9}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/64/sunny.png', 'comment': 'Clear'}, 'next_days': [{'day': 'Wednesday', 'comment': 'Cloudy', 'max_temp': {'c': 15, 'f': 59}, 'min_temp': {'c': 11, 'f': 52}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy.png'}, {'day': 'Thursday', 'comment': 'Clear with periodic clouds', 'max_temp': {'c': 21, 'f': 70}, 'min_temp': {'c': 11, 'f': 52}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/sunny_s_cloudy.png'}, {'day': 'Friday', 'comment': 'Clear with periodic clouds', 'max_temp': {'c': 18, 'f': 64}, 'min_temp': {'c': 11, 'f': 52}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/sunny_s_cloudy.png'}, {'day': 'Saturday', 'comment': 'Cloudy with brief rain', 'max_temp': {'c': 16, 'f': 61}, 'min_temp': {'c': 9, 'f': 48}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy_s_rain.png'}, {'day': 'Sunday', 'comment': 'Clear with periodic clouds', 'max_temp': {'c': 16, 'f': 61}, 'min_temp': {'c': 9, 'f': 48}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/sunny_s_cloudy.png'}, {'day': 'Monday', 'comment': 'Cloudy', 'max_temp': {'c': 14, 'f': 57}, 'min_temp': {'c': 8, 'f': 46}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy.png'}, {'day': 'Tuesday', 'comment': 'Cloudy', 'max_temp': {'c': 19, 'f': 66}, 'min_temp': {'c': 9, 'f': 48}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy.png'}, {'day': 'Wednesday', 'comment': 'Cloudy with brief rain', 'max_temp': {'c': 22, 'f': 72}, 'min_temp': {'c': 13, 'f': 55}, 'iconURL': 'https://ssl.gstatic.com/onebox/weather/48/cloudy_s_rain.png'}], 'contact_author': {'email': 'communication.with.users@gmail.com', 'auth_note': 'Mail me for feature requests, improvement, bug, help, ect... Please tell me if you want me to provide any other free easy-to-use API services'}, 'data_source': 'https://www.google.com/search?lr=lang_en&q=weather+in+toyoko'}

# %%
forecast = weather["currentConditions"]["comment"]

# %%
forecast
# Out:
# 'Clear'

# %%
# open file with keys and set the path to your credentials JSON file
credentials = "spotify_keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
# read the keys and assign each to a variable
# A redirect URI, or reply URL, is the location where the authorization server sends the user once the app has been 
# successfully authorized and granted an authorization code or access token.
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)
# Out:
# Enter the URL you were redirected to: https://www.google.com/?code=AQDM74sTi5xmGhzu6LByE-zUb8z2O_7bbVrsJEZnJMUVwazYhG7MDfAlbiRq7labjSFq1B4fcDLz-MhfbU--R6vlHsTVihQDisvHSvPpGiTSDLHHeer1L3eUtIsrgpRPNr3AQ0LHHTxcJG1vDYS4ZM_IrPrVbLwwKTwNbcYCstdv7P909kAT_2_YSENmYBWCB3H-MHvRuvWnyPg6iMykz-D-2hCSVcwaoAmPlVF5HrEanRdMpCNG9y2QyZtoSDBBdn6t04pBROclP4mbpika1J-qo_Yvkbg

# %%
# Create OAuth Object
# oauth_object = spotipy.SpotifyOAuth(client_id, client_secret, redirectURI)
# Create token
# token_dict = oauth_object.get_cached_token()
# token = token_dict['access_token']
# print(token_dict)
# Create Spotify Object
sp = spotipy.Spotify(auth=token)

# %%
devices = sp.devices()
print(devices)
deviceID = devices['devices'][0]['id']
# Out:
# {'devices': [{'id': 'e5b37d6f7c343ca905a77f3cefffd23aeee3fe06', 'is_active': True, 'is_private_session': False, 'is_restricted': False, 'name': 'KSULLIVAW10M', 'type': 'Computer', 'volume_percent': 100}]}

# %%
# learn about more query strings for spotify here: https://developer.spotify.com/documentation/web-api/reference/#/operations/search
track_results = sp.search(q=forecast, type='track', limit=50)

# %%
tracks = track_results['tracks']['items']

# %%
tracks[0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#     'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#     'id': '2RdwBSPQiwcmiDo9kixcl8',
#     'name': 'Pharrell Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0lrmy4pJINsFzycJvttX2W'},
#   'href': 'https://api.spotify.com/v1/albums/0lrmy4pJINsFzycJvttX2W',
#   'id': '0lrmy4pJINsFzycJvttX2W',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e8107e6d9214baa81bb79bba',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e8107e6d9214baa81bb79bba',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e8107e6d9214baa81bb79bba',
#     'width': 64}],
#   'name': 'G I R L',
#   'release_date': '2014-03-03',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:0lrmy4pJINsFzycJvttX2W'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#    'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#    'id': '2RdwBSPQiwcmiDo9kixcl8',
#    'name': 'Pharrell Williams',
#    'type': 'artist',
#    'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 232720,
#  'explicit': False,
#  'external_ids': {'isrc': 'USQ4E1300686'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/60nZcImufyMA1MKQY3dcCH'},
#  'href': 'https://api.spotify.com/v1/tracks/60nZcImufyMA1MKQY3dcCH',
#  'id': '60nZcImufyMA1MKQY3dcCH',
#  'is_local': False,
#  'name': 'Happy - From "Despicable Me 2"',
#  'popularity': 80,
#  'preview_url': 'https://p.scdn.co/mp3-preview/fdc94bcbfd0c39af16ac4d2224152c17066bcce7?cid=bc87ffdf34f1428995ef0f8e9b127718',
#  'track_number': 5,
#  'type': 'track',
#  'uri': 'spotify:track:60nZcImufyMA1MKQY3dcCH'}

# %%
# URI = uniform resource identifier
track_selection_list = []
track_art = []

for song in tracks:
    track_selection_list.append(song['uri'])
    track_art.append(song['album']['images'][0]['url'])

# %%
my_playlist = sp.user_playlist_create(user=username, name=forecast, public=True,
                                      description="Songs for the weather")
results = sp.user_playlist_add_tracks(username, my_playlist['id'], track_selection_list)
print(results)
# Out:
# {'snapshot_id': 'Myw3YmNjZTU4Yjk4ZDQ0ODAyMmIxZWRiYmU4YzEwNWM1N2Y1YWY4NGUw'}

# %%
print(my_playlist)
# Out:
# {'collaborative': False, 'description': 'Songs for the weather', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/61zxKHa9BAdEtHOMiVtISz'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/61zxKHa9BAdEtHOMiVtISz', 'id': '61zxKHa9BAdEtHOMiVtISz', 'images': [], 'name': 'Clear', 'owner': {'display_name': 'katsully1', 'external_urls': {'spotify': 'https://open.spotify.com/user/katsully1'}, 'href': 'https://api.spotify.com/v1/users/katsully1', 'id': 'katsully1', 'type': 'user', 'uri': 'spotify:user:katsully1'}, 'primary_color': None, 'public': True, 'snapshot_id': 'MSw3ZDYyYjM3NDIxNTQ2Yjk1YjBmNDM0OTgwYjIyYjNhZWNkMzU1NzJi', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/61zxKHa9BAdEtHOMiVtISz/tracks', 'items': [], 'limit': 100, 'next': None, 'offset': 0, 'previous': None, 'total': 0}, 'type': 'playlist', 'uri': 'spotify:playlist:61zxKHa9BAdEtHOMiVtISz'}

# %%
# sp.start_playback(deviceID, None, track_selection_list)
webbrowser.open(my_playlist['external_urls']['spotify'])
# Out:
# True
