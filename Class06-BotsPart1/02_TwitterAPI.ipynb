# %%
import tweepy
import json
# most pythonistas will rename pandas as pd and numpy as np for short (you don't have to)
import pandas as pd
import numpy as np

# %%
# open file with keys and set the path to your credentials JSON file
# see example.json for formatting
# you'll need to replace my file with yours
credentials = "keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
# read the keys and assign each to a variable
bearer_token = api_tokens["bearer_token"]
api_key = api_tokens["api_key"]
api_secret = api_tokens["api_secret"]
access_token = api_tokens["access_token"]
access_secret = api_tokens["access_secret"]

# %%
client = tweepy.Client(
    bearer_token=bearer_token,
    consumer_key=api_key,
    consumer_secret=api_secret,
    access_token=access_token,
    access_token_secret=access_secret,
    return_type = dict
)

# %% [markdown]
# Let's look up the 100 most recent tweets using #London
# <br/>We're going to use the search_recent_tweets() function and 4 parameters, they are:
# <br/><b>query: </b><a href="https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query">Learn more about building queries here</a>
# <br/><b>max_results: </b>The maximum number of search results to be returned by a request. A number between 10 and 100. By default, a request response will return 10 results.
# <br/><b>tweet_fields: </b><a href="https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/tweet">See all tweet fields here</a>
# <br/><b>user_fields: </b><a href="https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/user">See all user fields here</a>

# %%
tweets = client.search_recent_tweets(
    "#London",  
    max_results = 100,
    tweet_fields = ['author_id', 'created_at', 'text', 'source', 'lang', 'geo'],
    user_fields = ['name', 'username', 'location', 'verified']
)

# %%
tweets
# Out:
# {'data': [{'id': '1565709990190632960',
#    'author_id': '221769622',
#    'lang': 'de',
#    'created_at': '2022-09-02T14:35:25.000Z',
#    'source': 'Instagram',
#    'text': '#london #madness of #fear.\nDas war das Thema. \nUnd das, dass Ergebnis.\n\n#kikunst \n.\n.\n.\n.\n#aiart #aiartwork #kunst #hoefellner #hankhoefellner #künstlicheintelligenz #bilder #computerkunst https://t.co/ncR8jwm1Ka'},
#   {'id': '1565709949094793217',
#    'author_id': '1565703102287814656',
#    'lang': 'de',
#    'geo': {'place_id': '4df040baa097e37a'},
#    'created_at': '2022-09-02T14:35:16.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'Monaco NFT Club #Montecarlo #Monaco #Art #NFTART #nft #Dubai #London #Paris #Genève #Suisse #Crypto #Bitcoin #MonacoNFTClub #BillionaireClubMonaco #Billionaire #CasinoMonteCarlo #Finance #Business #Design #nftart #NFT #NYC #USA #UAE #UK #Switzerland https://t.co/u9RTtpgFf2'},
#   {'id': '1565709938231484423',
#    'author_id': '542913162',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:35:13.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @ActScribblerDJ: #PsychologicalThriller #love #spy #crime #revenge #WW2 #ColdWar #sixties #London #Berlin\n\nSaga meets Series\nTHERE IS NO…'},
#   {'id': '1565709934259486721',
#    'author_id': '104637487',
#    'lang': 'qme',
#    'created_at': '2022-09-02T14:35:12.000Z',
#    'source': 'Hootsuite Inc.',
#    'text': '#Fun #Stickers #Kids #Crafts\n\nhttps://t.co/7YokR7iLdr\n\n#Exeter #Wales #Sussex #Scotland #Surrey #Essex #Lincoln #Norfolk #Cornwall #Guildford #Bizitalk #Birmingham #Kent #Cheshire #London #Liverpool #CraftBizParty #Cumbria #Preston #Devon #Wigan #firsttmaster #Newcastle #Hull https://t.co/cypdZmJBQr'},
#   {'id': '1565709853087219713',
#    'author_id': '1563372748923346944',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:34:53.000Z',
#    'source': 'Twitter Web App',
#    'text': 'RT @HATCmedia: The one and only @AlfieBlue8 to HATC Festival 2022.\n\n25th September 2022 \n@scalaldn \n2pm-11pm\n\nEarly bird tickets are on sal…'},
#   {'id': '1565709795461632000',
#    'author_id': '4340139628',
#    'lang': 'qht',
#    'created_at': '2022-09-02T14:34:39.000Z',
#    'source': 'Twitter for iPhone',
#    'text': '-\n-\n-\n-\n\n#headshotsmatter #photographer #follow #photooftheday #photography #headshot #headshots\n#manchester #london #actor #portrait #actorheadshot #acting #studio #shallowdepthoffield #canon \n#actorlifestyle #naturallight #canon5dmk3'},
#   {'id': '1565709787228246020',
#    'author_id': '3374619071',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:34:37.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Have you seen Nehal (11) reported missing from #ThorntonHeath (#Croydon) (#London) on September 2, 2022? (Call Metropolitan police on 101 quoting 22MIS031213) https://t.co/IuuVSzG0Ac https://t.co/QcnmoFBk12'},
#   {'id': '1565709767439523841',
#    'author_id': '1130744746501201920',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:34:32.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Is Your Vehicle Facing An MOT Failure? We, Will, Buy It From You And Pay the Best Prices For Your Scrap Vehicle!\n\n☎️ 0800 884 1007\n🌐 https://t.co/idMGRx6aFI\n\n#bracknell #henley #london #sidcup #scrapmycar #scrapcar #scrapcarcollection #scraping #simple #scrapmycar #scrapcar https://t.co/yCXHqCTvMI'},
#   {'id': '1565709754613252101',
#    'author_id': '2907203900',
#    'lang': 'en',
#    'geo': {'place_id': '765e433145f71368'},
#    'created_at': '2022-09-02T14:34:29.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'Every encounter is fate,\n#london https://t.co/6kmHAYXIPD'},
#   {'id': '1565709743959982080',
#    'author_id': '2768117544',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:34:27.000Z',
#    'source': 'Twitter Web App',
#    'text': 'RT @7Ten: The vibe at @FreeplayC is grittier &amp; grimier than your average arcade. This isn\'t a "please everyone, yet focus on no one" redemp…'},
#   {'id': '1565709673004777472',
#    'author_id': '702076687492714496',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:34:10.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Happy #Friday everyone!🤗Order an #arrangement to bring #positivevibes into your home! 💐😍🤗☺️\n#fresh #flowers #freshflowers #flowerdelivery #freedelivery #uk #london #ukdelivery https://t.co/8H5V1quHe7'},
#   {'id': '1565709466451992579',
#    'author_id': '1071885537550712832',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:33:20.000Z',
#    'source': 'Twitter for Android',
#    'text': 'View from the London Eye \n\n#London \n#iconico https://t.co/VXi8SNvK7r'},
#   {'id': '1565709458923208709',
#    'author_id': '1564801658009288706',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:33:19.000Z',
#    'source': 'Twitter Web App',
#    'text': 'RT @mnicoletos: I would like to thank everyone at @Blockworks_ for the beautiful event in #London last week and, more specifically, @JackFa…'},
#   {'id': '1565709447485394944',
#    'author_id': '706850238',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:33:16.000Z',
#    'source': 'Twitter for iPad',
#    'text': 'RT @DogsofTooting: We have an emergency Please  help us . #FindBenji @GrangewoodPark #ThorntonHeath #London @THeathChronicle @MissingPetsGB…'},
#   {'id': '1565709337980350464',
#    'author_id': '238025384',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:32:50.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @Venkatesh_WSS: Good morning from #london \u2066@Epikoregal\u2069 \u2066@ecomi_\u2069 \u2066@veve_official\u2069 \u2066@Kaloscope_nft\u2069 \u2066@getsetplay_io\u2069,\n\nExcited to meet o…'},
#   {'id': '1565709294661783555',
#    'author_id': '1000806396047253504',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:32:39.000Z',
#    'source': 'Instagram',
#    'text': 'This place is my favourite 🥰😻 Taking all the positivity from here ✌️😌 ⌚️#canarywharf #canarywharflondon #london🇬🇧 @ Canary Wharf Roof Garden https://t.co/yuUpMAlG3y'},
#   {'id': '1565709279641931777',
#    'author_id': '1383821266990161923',
#    'lang': 'qme',
#    'created_at': '2022-09-02T14:32:36.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @JosSDazArt1: #art  #arte #artwork  #digitalart  #Abstract  #decoracion  #ร่างทรง  #paint  #designer  #decor #GenshinImpact  #하나가되는순간_모두…'},
#   {'id': '1565709192174125056',
#    'author_id': '1296337493646692352',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:32:15.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @malleshoogurtha: Birthday Celebrations at East Ham #London #Uk #HBDJanasenaniPawanKalyan https://t.co/4Tn9NS1WVI'},
#   {'id': '1565709107264372738',
#    'author_id': '702916550504914944',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:31:55.000Z',
#    'source': 'HubSpot',
#    'text': "A message from our Knitter’s Circle 💌\n\n'We are a friendly group of knitters who crochet and cross stitch. All welcome on Saturdays at the Community Hub 10am - 1pm – just turn up, it's free!'\n\n#knitting #cafe #london https://t.co/YCHJEPutBe"},
#   {'id': '1565709079854649347',
#    'author_id': '1211077633204613121',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:31:48.000Z',
#    'source': 'booksbitcoin',
#    'text': 'RT @STXLDN: September tickets are available, with EARY BIRD DISCOUNTS!🥳\n\nCode is Law -V- Code &amp; Law — Stacks End of Summer After Party!👨\u200d💻…'},
#   {'id': '1565708954402955266',
#    'author_id': '3188155083',
#    'lang': 'fr',
#    'created_at': '2022-09-02T14:31:18.000Z',
#    'source': 'Twitter Web App',
#    'text': '#VendrediLecture : «\xa0Dernière nuit à Soho\xa0» de Fiona Mozley. Un régal ! #rentreelitteraire2022 #London #Soho @EdJoelleLosfeld @pchevilley https://t.co/OaIiVx8TAJ'},
#   {'id': '1565708944676454402',
#    'author_id': '1100366806466867200',
#    'lang': 'ur',
#    'created_at': '2022-09-02T14:31:16.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @KhyberNews247: حمزہ شہباز لندن سے واپس لاہور پہنچ گئے\n\n#KhyberTv #hamzashehbaz #london #lahore'},
#   {'id': '1565708942503723009',
#    'author_id': '241736598',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:31:16.000Z',
#    'source': 'Twitter for iPad',
#    'text': 'The search for speed.\n#Greenwich #Navalmaritimemuseum #London https://t.co/PXgKGIbH14'},
#   {'id': '1565708938884141057',
#    'author_id': '1537100486226083841',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:31:15.000Z',
#    'source': 'Twitter Web App',
#    'text': 'The iconic bus!\n#london #doubledeckerbus #redbus #England #Travel #londonroads #outdoorphotography #photo #travelblogger #art #photography #photographie #canonphotography #canon #unitedkingdom #Foto #TravelStory #travellers #citybreaks #bestdestinations https://t.co/HkIXypdDyX'},
#   {'id': '1565708916360716295',
#    'author_id': '54895582',
#    'lang': 'tr',
#    'created_at': '2022-09-02T14:31:09.000Z',
#    'source': 'Twitter Web App',
#    'text': 'People who do not value you are not supporting you.  People who do not support you do not want you to win.\nSize değer vermeyen sizi desteklemiyordur.  Sizi desteklemeyen sizin kazanmanızı istemiyordur.\n#Sunset  #London\n#love \n#instagood \n#fashion\n#photooftheday \n#beautiful \n#art https://t.co/UPgQnCGkEp'},
#   {'id': '1565708742842269698',
#    'author_id': '104637487',
#    'lang': 'qme',
#    'created_at': '2022-09-02T14:30:28.000Z',
#    'source': 'Hootsuite Inc.',
#    'text': '#Sealife #FuzzyArt #holidays #Kids #Crafts\n\nhttps://t.co/yZscuPAehv \n\n#Sealife #Fish #Fishing #Crafts #Fuzzyart #Exeter #Wales #Sussex #Scotland #Lincoln #Norfolk #Cornwall #Bizitalk #Kent #London #Liverpool #CraftBizParty #Cumbria  #Devon #FirstTMaster #Hull https://t.co/c9VfDVZZFU'},
#   {'id': '1565708675460784128',
#    'author_id': '1389671817741283343',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:30:12.000Z',
#    'source': 'CONTENIVE',
#    'text': 'Get your house sale moving with our house buying service\n\nFast offer &amp; quick completion\n\nhttps://t.co/UMLqN2E5Up\n\n#london #Birmingham #glasgow #liverpool #bristol #manchester #Sheffield #leeds #Edinburgh #Leicester #Coventry #bradford https://t.co/joVVghc6rB'},
#   {'id': '1565708666237485057',
#    'author_id': '1489236832634167297',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:30:10.000Z',
#    'source': 'The Jazz Century',
#    'text': 'If you were streaming https://t.co/gQEZOjVGLt you’d be hearing Days Of Wine And Roses (1968) by Johnny Smith and your ears would be filled with joy. Free internet radio playing 100 years of Jazz #jazz #music #free #listen #london #paris #cook #recipe https://t.co/4psDZjPikb'},
#   {'id': '1565708628501348353',
#    'author_id': '1021752005893783552',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:30:01.000Z',
#    'source': 'Zoho Social',
#    'text': '@TivoliGroupLtd will be #exhibiting at our upcoming #London Careers Fair!⚡️\n\n📍 Tottenham Hotspur Stadium\n🗓 Thursday 3rd November 2022\n\nLooking for a #Career? Our events are FREE to attend - secure your ticket via https://t.co/KXSoNttC8p 🤩 https://t.co/K6q2UUuIUj'},
#   {'id': '1565708624843776001',
#    'author_id': '799648935140872192',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:30:00.000Z',
#    'source': 'Twitter for Advertisers',
#    'text': 'Latest job in #London :The Marketing Department London @tmdca is #recruiting a commercially minded individual with exceptional sales promotion, communication, and time management skills to support the Senior TMD Management Team and lead on customer service #diversityandinclusion'},
#   {'id': '1565708624772612099',
#    'author_id': '1087382633800179712',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:30:00.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Australian alternative rock singer-songwriter Alex Lahey is taking her relatable pop-punk anti-anthems to Omeara, #London in September 2022. @AlexLahey \n\n🎟️https://t.co/bXMlw8y7EQ\n\nhttps://t.co/lzWFlC8ypi'},
#   {'id': '1565708598201958400',
#    'author_id': '1222182111743893504',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:29:53.000Z',
#    'source': 'Twitter for Android',
#    'text': "RT @ColorsTVUK: Rubina was waiting for this day since 8 years!🤩 Let's wish her good luck on her new journey in Jhalak Dikhhla Jaa.  Watch #…"},
#   {'id': '1565708507902615553',
#    'author_id': '1449961936070774786',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:29:32.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @DaniLavigne77: Ready to go exploring #London any recommendations? x https://t.co/Y4E9jiD8LG'},
#   {'id': '1565708506874781697',
#    'author_id': '270876142',
#    'lang': 'in',
#    'created_at': '2022-09-02T14:29:32.000Z',
#    'source': 'Twitter for Android',
#    'text': 'Ayo ibadah yukkk 🔥🔥🔥\n@psobaja @pdt_obaja_ts @gbika_ind \n#America #Australia #Austria #China #Chicago #HongKong #Indonesia #India #korean #melbourne #Japan #singapore #Philadelphia #philippine #UnitedNations #UnitedStates #Paris #london #Laos #Malaysia https://t.co/kFmYtqN8EO'},
#   {'id': '1565708456702648323',
#    'author_id': '285299025',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:29:20.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'Sending everyone positive Friday vibes with a closer look at my ticket design for @NFT_NYC 🙌🎨💫 #nftart #NFTartist #london #nftlondon #PositiveVibes https://t.co/7ns0vdoAsr'},
#   {'id': '1565708451417817094',
#    'author_id': '1448746533692846084',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:29:18.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @AdoptionsUk: Please retweet to help Sandy find a home #HAREFIELD #LONDON #UK \n\nAffectionate Lurcher aged 1-2, she can live with childre…'},
#   {'id': '1565708401522393088',
#    'author_id': '1151964004526514181',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:29:07.000Z',
#    'source': 'BenBots',
#    'text': "RT @talesjukebox: Hey fellow #ttrpg fans. I'm running a 5E prison break (with added zombies) on 6 September at a great game café in #Deptfo…"},
#   {'id': '1565708348711993346',
#    'author_id': '62808000',
#    'lang': 'en',
#    'geo': {'place_id': '3eb2c704fe8a50cb'},
#    'created_at': '2022-09-02T14:28:54.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'Meet Stella from Stratford E15 - the kindest woman in #London who helped us get from our random parking location to lunch in the City. I adore the kindness of strangers and she made my day - please give her a shout out @JasonRosam https://t.co/cKKDO6feoe'},
#   {'id': '1565708313416896513',
#    'author_id': '1529402449357848576',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:28:46.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Men Stylish Casual Male Sneakers Shoes Cushion Shoes https://t.co/eI1z1i42nf \n#UnitedKingdom #fashion  #style  #ootd  #instafashion #USA #fashionblogger  #Unitedkingdom #outfit  #fashionista  #streetstyle  #stylish #instastyle #trend  #styles  #lookbook  #fridaymorning #London'},
#   {'id': '1565708301643431936',
#    'author_id': '913315369758154752',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:28:43.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Hello, #Friday!☺️ #Brighten the day of your #family and #friends with some #lovely #charming #colourful and #fresh #flowers! 💐😍☺️😉\n#fresh #flowers #freshflowers #flowerdelivery #freedelivery #uk #london #ukdelivery https://t.co/aAghVQOolD'},
#   {'id': '1565708082935652352',
#    'author_id': '133007577',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:27:51.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @nottsey: Personal Top 22 Films shown @FrightFest 2022 part 1\n\n1 Piggy @Carlota_Pereda \n2 The Leech @epennycoff @GrahamSkipper\n3 Barbari…'},
#   {'id': '1565708019626909696',
#    'author_id': '2149217436',
#    'lang': 'qht',
#    'created_at': '2022-09-02T14:27:35.000Z',
#    'source': 'Twitter Web App',
#    'text': '#Amega #Entertainment #IAAPA #IAAPAexpo #London #themepark #amusementpark #VR #VRgame #VRracing #motorsport #simracing #racingsim #formula #Offroad #race #racing #rallylife #racecar #iracing #simulator #game #gamers #gameplay #gaming #6DOF #esports #fair #event'},
#   {'id': '1565707974638796801',
#    'author_id': '2314375832',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:27:25.000Z',
#    'source': 'TweetDeck',
#    'text': 'RT @JewelsGiftBox: #Kids will have a great time with #DottyArt #Crafts\n\nhttps://t.co/txApW2mkbb\n\n#Exeter #Wales #Sussex #Scotland #Surrey #…'},
#   {'id': '1565707962143883264',
#    'author_id': '2314375832',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:27:22.000Z',
#    'source': 'TweetDeck',
#    'text': 'RT @JewelsGiftBox: Halloween Spider Fuzzy Art #Kids #Crafts Kit \n\nhttps://t.co/7YokR7iLdr\n\n#Exeter #Wales #Sussex #Scotland #Surrey #Essex…'},
#   {'id': '1565707948755648517',
#    'author_id': '2314375832',
#    'lang': 'qme',
#    'created_at': '2022-09-02T14:27:19.000Z',
#    'source': 'TweetDeck',
#    'text': 'RT @JewelsGiftBox: #Sealife #Holiday  #Crafts\n\nhttps://t.co/7YokR7Am4Z\n\n#Exeter #Wales #Sussex #Scotland #Surrey #Essex #Lincoln #Norfolk #…'},
#   {'id': '1565707942430740480',
#    'author_id': '193131162',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:27:17.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @nottsey: Personal Top 22 Films shown @FrightFest 2022 part 1\n\n1 Piggy @Carlota_Pereda \n2 The Leech @epennycoff @GrahamSkipper\n3 Barbari…'},
#   {'id': '1565707912160346113',
#    'author_id': '2314375832',
#    'lang': 'qme',
#    'created_at': '2022-09-02T14:27:10.000Z',
#    'source': 'TweetDeck',
#    'text': 'RT @JewelsGiftBox: #Crafts #Kids #CrossStitch \n\nhttps://t.co/7YokR7iLdr\n\n#Exeter #Wales #Sussex #Scotland #Surrey #Essex #Lincoln #Norfolk…'},
#   {'id': '1565707861870710787',
#    'author_id': '1443647500825604097',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:26:58.000Z',
#    'source': 'Twitter Web App',
#    'text': "It's nearly 10 years since I met my hero @OlafurArnalds &amp; interviewed him for @echoesanddust I was young/naive but it was one of the biggest pinch me moments of my life! https://t.co/SMHY0FVJ9q #olafurarnalds #hero #musicjournalism #music #love #reflection #londonlife #london"},
#   {'id': '1565707851993157637',
#    'author_id': '1062723704134795273',
#    'lang': 'et',
#    'created_at': '2022-09-02T14:26:56.000Z',
#    'source': 'Hootsuite Inc.',
#    'text': "From being his idol, Pierre-Emerik Aubameyang is now Wesley Fofana's teammate!👏👊\n\n#Pierre-EmerikAubameyang #fofana #aubameyang #chelsea #barcelona #premierleague #laliga #transfers #DeadlineDay #barca #london #blaugrana #helpbet https://t.co/TvQDagMV1b"},
#   {'id': '1565707836654604288',
#    'author_id': '2328730903',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:26:52.000Z',
#    'source': 'Twitter Web App',
#    'text': 'RT @MarinersTorquay: #EnglishRiviera 🌴 - #Devon #UK \n\nSo much to do...\n&gt;https://t.co/UIBbokwsZJ \n\n#Travel #Holiday #Family #StayCation #Lon…'},
#   {'id': '1565707762851811329',
#    'author_id': '4787351246',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:26:34.000Z',
#    'source': 'Twitter for Android',
#    'text': 'Co Produced By:\nGravity Zero Entertainment\n\n#mithunchakraborty  #SalimMerchant #SulaimanMerchant #SalimsSulaimanMusic #RajeevGoswami #BSubhash @thebappilahiri @YoodleeFilms @Sadlers_Wells #Irfanksiddiqui\n#DiscoDancer\n#Broadway\n#TheMusical\n#London\n#MithunChakraborty\n#BappiLahiri'},
#   {'id': '1565707664872673286',
#    'author_id': '1389671817741283343',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:26:11.000Z',
#    'source': 'CONTENIVE',
#    'text': 'Get your house sale moving with our house buying service\n\nFast offer &amp; quick completion\n\nhttps://t.co/UMLqN2E5Up\n\n#estateagents #estateagent #propertyforsale #forsale #London #uk #england #scotland  #manchester #Birmingham #housing #ukhousing #home #property #house #homesforsale https://t.co/ggg6cvGxWJ'},
#   {'id': '1565707592818737156',
#    'author_id': '926168267730948096',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:25:54.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @AdoptionsUk: Please retweet to help Sandy find a home #HAREFIELD #LONDON #UK \n\nAffectionate Lurcher aged 1-2, she can live with childre…'},
#   {'id': '1565707552867876868',
#    'author_id': '894936529377914880',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:25:44.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @STXLDN: September tickets are available, with EARY BIRD DISCOUNTS!🥳\n\nCode is Law -V- Code &amp; Law — Stacks End of Summer After Party!👨\u200d💻…'},
#   {'id': '1565707393358512129',
#    'author_id': '295786768',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:25:06.000Z',
#    'source': 'Twitter Web App',
#    'text': '@meghanor I used to go to the Cyberia cybercafe in London in 1994. It was one of the first places I could get online, before internet access was easily available at home/office. I remember using Alta Vista search engine, Word Perfect word processor and floppy disks. #cyberia #London https://t.co/zMhZEcziQg'},
#   {'id': '1565707196352143362',
#    'author_id': '940599816907837442',
#    'lang': 'ur',
#    'created_at': '2022-09-02T14:24:19.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @DialogueUrdu: برطانوی سفارت کرسچن ٹرنر کا سیلاب زدگان کیلیے اردو زبان میں پیغام\n\n#DialogueUrdu #London #PakistanFloods #floodinsindh #B…'},
#   {'id': '1565707137120194562',
#    'author_id': '1401968602392236040',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:24:05.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @PeteCityPrice: Last time I went to the @can_liverpool I put a video up on my #tiktok  of their Fish &amp; Chips  and I got 72,000 hits and…'},
#   {'id': '1565707127053815809',
#    'author_id': '19443848',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:24:03.000Z',
#    'source': 'Buffer',
#    'text': '#eOffice Holborn 📍 As #London’s historic law district, Holborn is a bustling mix of legal buildings and offices, such as the imposing Royal Courts of Justice and nearby Inns of Court ⚖️ #linkinbio https://t.co/w5ND0x07lB'},
#   {'id': '1565707062407053312',
#    'author_id': '375854213',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:23:47.000Z',
#    'source': 'Twitter for iPad',
#    'text': 'RT @HousingITguy: Capital’s council housing stock has shrunk by almost 6% over the past decade due to homes sold under Right to Buy https:/…'},
#   {'id': '1565707006316535808',
#    'author_id': '822362102',
#    'lang': 'qme',
#    'created_at': '2022-09-02T14:23:34.000Z',
#    'source': 'Twitter Web App',
#    'text': 'RT @fifross: #london #FridayFeeling https://t.co/CAttsqPaLH'},
#   {'id': '1565706956794433536',
#    'author_id': '1448660500242317320',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:23:22.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Here is Langley’s latest project update. Our client is a groundworks sub-contractor. They are undertaking the sub-structure and RC frame for this five-storey development.\n#Construction #groundworks #quantitysurveying #london https://t.co/bwhi5OlFEH'},
#   {'id': '1565706886363680770',
#    'author_id': '912689310457049088',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:23:05.000Z',
#    'source': 'Twitter Web App',
#    'text': 'Hello, #Friday! ☺️ Express your #love and #care by #surprising your #specialpeople with a #lovely #flower #gift! 💐😍☺️🤗\n#fresh #flowers #freshflowers #flowerdelivery #freedelivery #uk #london #ukdelivery https://t.co/2hII37Df4o'},
#   {'id': '1565706829069516800',
#    'author_id': '891971864528080898',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:22:52.000Z',
#    'source': 'TweetDeck',
#    'text': 'RT @PowerdayPLC: Tune into BBC Radio London at 3:30pm today, to hear from professional boxer Shannon Courtenay &amp; Daisy Williams from Hey Gi…'},
#   {'id': '1565706815228239872',
#    'author_id': '979351469618028544',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:22:48.000Z',
#    'source': 'PropertyLion',
#    'text': '#UKPLLondon\n\nTOTAL REDUCTION: 13.25%\n\nADDRESS: Pollard Road, #London, N20\n\nSTATUS: Reduced yesterday\n\nINITIAL PRICE: £1095000\nNEW PRICE: £1000000 to £949950, Down 5.00%\n\nPOSTCODE: N20 \n\nhttps://t.co/DhlrargKjT'},
#   {'id': '1565706774593748992',
#    'author_id': '373033461',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:22:39.000Z',
#    'source': 'Twitter for iPad',
#    'text': "RT @MayadeenEnglish: The destructive nature of 'hush culture' on No 10 protected Boris #Johnson's cabinet and party from being held account…"},
#   {'id': '1565706724975198210',
#    'author_id': '1475788963',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:22:27.000Z',
#    'source': 'Twitter for iPhone',
#    'text': "RT @iyoba4u: 1/3\n\nA Must To Read‼️\n\n📍Renewed #TPLF Terror War Against The #Ethiopia'n People\n\nBy @peeblesgraham, via @NatCounterPunch\n\n👉 Wi…"},
#   {'id': '1565706719413649411',
#    'author_id': '153843805',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:22:25.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @MissingPetsGB: 🐕 FORREST went #missing \n30 Aug 2022, 8:30pm during a walk in Eel Brook common area #London #SW6\nHe was spooked by a big…'},
#   {'id': '1565706683929997312',
#    'author_id': '5373782',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:22:17.000Z',
#    'source': 'Instagram',
#    'text': 'Fresh paint from #Shoreditch #London #E1 #bigartmob #streetart #graffiti #skeleton #birdman #smiley @ Shoreditch https://t.co/Ea8nwu8UA6'},
#   {'id': '1565706577813848066',
#    'author_id': '1024581253',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:21:52.000Z',
#    'source': 'Twitter for Android',
#    'text': 'RT @DogsofTooting: We have an emergency Please  help us . #FindBenji @GrangewoodPark #ThorntonHeath #London @THeathChronicle @MissingPetsGB…'},
#   {'id': '1565706500756348928',
#    'author_id': '970903623071776769',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:21:33.000Z',
#    'source': 'Twitter Web App',
#    'text': 'RT @SAI_Patiala: SAI NS NIS #Patiala has opened the registrations for Two Week Intensive #Advance Sports Massage Course #Second time in Ind…'},
#   {'id': '1565706445676580866',
#    'author_id': '19500397',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:21:20.000Z',
#    'source': 'CORE ListingMachine',
#    'text': 'We are looking for a buyer on 2310 Sequoya Trail #London #OH  #realestate https://t.co/ukEWoqNGcL https://t.co/l3TtgjwYSU'},
#   {'id': '1565706439410212866',
#    'author_id': '706530753866305538',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:21:19.000Z',
#    'source': 'Twitter for Android',
#    'text': "RT @iyoba4u: 1/3\n\nA Must To Read‼️\n\n📍Renewed #TPLF Terror War Against The #Ethiopia'n People\n\nBy @peeblesgraham, via @NatCounterPunch\n\n👉 Wi…"},
#   {'id': '1565706429146845184',
#    'author_id': '281182642',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:21:16.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @bbcshowstours: Alexei Sayle returns behind the counter of his Imaginary Sandwich Bar this September to bring an order of stand-up, memo…'},
#   {'id': '1565706321818951682',
#    'author_id': '828005654954651652',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:51.000Z',
#    'source': 'London PLOW',
#    'text': "Gordon's move to Chelsea 'never close' - Lampard (BBC Sport)\n\nEverton boss Frank Lampard said Anthony Gordon's potential move to Chelsea &amp;quot;never got c...\n\nAdd your highlights:\nhttps://t.co/3OK6NkiRCQ\n #London #UK #ldn"},
#   {'id': '1565706214822260736',
#    'author_id': '19104804',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:25.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @HarrisonPhair: Canary Wharf #ElizabethLine #Station\n🚝🛤🚆🚄🚅\n#nikon #z6ii 8-15 #fisheye \n#Architecture #Circle #Indoors #CanaryWharf #cros…'},
#   {'id': '1565706187638816768',
#    'author_id': '568862838',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:19.000Z',
#    'source': 'Twitter for Android',
#    'text': 'From #nyc @TheGarden to #london @wembleystadium @foofighters 4ever! In da cue getting geared up for the #taylorhawkinstribute tomorrow #crazypantsfortalyor #LFG 🤘🤘 https://t.co/cVpaL14de3'},
#   {'id': '1565706176343547904',
#    'author_id': '2534815279',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:16.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @nottsey: Personal Top 22 Films shown @FrightFest 2022 part 1\n\n1 Piggy @Carlota_Pereda \n2 The Leech @epennycoff @GrahamSkipper\n3 Barbari…'},
#   {'id': '1565706163299164164',
#    'author_id': '1108375779581276161',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:13.000Z',
#    'source': 'Hootsuite Inc.',
#    'text': "Come and join us at our next customer event!\n\nVirtual insanity or back to humanity?\n\nCan't make it in person, why not join us remotely?\n\nSign up here: https://t.co/6KaQcZm0ux\n\nRemote - https://t.co/km0t5qZ2EL\n\n#event #london #customerservice #cx #cs #business https://t.co/yDgOFuyoFV"},
#   {'id': '1565706139635007488',
#    'author_id': '942963521905553408',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:07.000Z',
#    'source': 'Agorapulse app',
#    'text': '“#Chinese billionaires have always treated #Singapore like a hotel, just like the #Russians in #London” — “Now, they are looking to become permanent residents.”\n\n@psb_dc @BetaMoroney\n@efipm @BrettKing\n@spirosmargaris\n@jimmarous\n#fintech #finserv https://t.co/usMsFJdBjT'},
#   {'id': '1565706132030722050',
#    'author_id': '822474083417935873',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:05.000Z',
#    'source': 'TweetDeck',
#    'text': 'RT @ehatourist: #Canterbury Day Trip from London, #England – Travel Guide, Things to Do, How to Get There, Tours, &amp; More #travel via @HeyJo…'},
#   {'id': '1565706110966939650',
#    'author_id': '2180084605',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:00.000Z',
#    'source': 'SocialChamp IO ',
#    'text': "BFI London Film Festival: 12 Must-See Movies From 'Knives Out' to 'Pinocchio' - https://t.co/kLU0ymnu2o  -  #LondonFilmFestival #BFI #London #Films #Movies #LFF"},
#   {'id': '1565706109985464320',
#    'author_id': '1148040037105147905',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:20:00.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @MrWhisper: Timeout in #Chinatown \n\n#London #streetphotography #fujifilm https://t.co/lgdWSCNIm4'},
#   {'id': '1565706080541368320',
#    'author_id': '464206700',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:19:53.000Z',
#    'source': 'Revive Old Post EHAT',
#    'text': '#Canterbury Day Trip from London, #England – Travel Guide, Things to Do, How to Get There, Tours, &amp; More #travel via @HeyJonTheGo https://t.co/4goFlbiP6B #daytrips #europe #history #london #museums'},
#   {'id': '1565706069938167809',
#    'author_id': '1893500400',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:19:51.000Z',
#    'source': 'Twitter Web App',
#    'text': "RT @natashapaveyuk: We went to the #London #LeadershipHustings because a third of #Pakistan is underwater and we've just had the hottest UK…"},
#   {'id': '1565706010949365760',
#    'author_id': '1148040037105147905',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:19:37.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @CreativeWisdom_: Dusk - Chinatown, London #streetphotography #streetphotographer #chinatown #London #dusk https://t.co/c9hmPAMSmL'},
#   {'id': '1565706006302277639',
#    'author_id': '166526819',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:19:35.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @gareth_p_jones: My new EP is (finally) out now and available on all your favourite music platforms. Link in bio ☝🏻Enjoy 🎶\n\n#semperviren…'},
#   {'id': '1565705944486510592',
#    'author_id': '1535648507977244674',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:19:21.000Z',
#    'source': 'Twitter for Android',
#    'text': "RT @iyoba4u: 1/3\n\nA Must To Read‼️\n\n📍Renewed #TPLF Terror War Against The #Ethiopia'n People\n\nBy @peeblesgraham, via @NatCounterPunch\n\n👉 Wi…"},
#   {'id': '1565705904024178689',
#    'author_id': '979351469618028544',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:19:11.000Z',
#    'source': 'PropertyLion',
#    'text': '#UKPLLondon\n\nTOTAL REDUCTION: 10.57%\n\nADDRESS: Oakfield Gardens, #London, N18\n\nSTATUS: Reduced yesterday\n\nINITIAL PRICE: £615000\nNEW PRICE: £585000 to £550000, Down 5.98%\n\nPOSTCODE: N18 \n\nhttps://t.co/IvbVvty6Tw'},
#   {'id': '1565705854699061249',
#    'author_id': '482041640',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:18:59.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @DogsofTooting: We have an emergency Please  help us . #FindBenji @GrangewoodPark #ThorntonHeath #London @THeathChronicle @MissingPetsGB…'},
#   {'id': '1565705839805071361',
#    'author_id': '1413328976215478273',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:18:56.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @mpangi_benito: I dream too ~Soho, London 2022\n#streetphoto #streetphotography #astreetminute #londonphotography #london https://t.co/NJ…'},
#   {'id': '1565705808213680137',
#    'author_id': '570746151',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:18:48.000Z',
#    'source': 'Twitter for Android',
#    'text': "RT @iyoba4u: 1/3\n\nA Must To Read‼️\n\n📍Renewed #TPLF Terror War Against The #Ethiopia'n People\n\nBy @peeblesgraham, via @NatCounterPunch\n\n👉 Wi…"},
#   {'id': '1565705803692122112',
#    'author_id': '3933732209',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:18:47.000Z',
#    'source': 'Twitter for Android',
#    'text': "But looking at how you don't like any criticism of how you have destroyed #London it really does not surprise me that you would support most hard working @TfL staff having disciplinary action when they simply say the truth about your underlings. @unitetheunion"},
#   {'id': '1565705645885734913',
#    'author_id': '85904666',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:18:10.000Z',
#    'source': 'Paiger',
#    'text': 'Hiring now! BMS Project Manager, £50k - £60k - #London. https://t.co/lJQskujFRV https://t.co/Vk1vPtNlDr'},
#   {'id': '1565705505061879808',
#    'author_id': '4188089543',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:17:36.000Z',
#    'source': 'Twitter for Android',
#    'text': "RT @ZeeNewsEnglish: Why London's #HeathrowAirport Terminal 2 was evacuated: \n\n#London  #aviation  \n\nhttps://t.co/PFOIANxfEq"},
#   {'id': '1565705383834013696',
#    'author_id': '825790602830815233',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:17:07.000Z',
#    'source': 'Radio King LiveTweet',
#    'text': 'https://t.co/irfayVqZLK | https://t.co/VIOKGWlB8I |\n#NowPlaying Alvin Clayton Pope feat. Nils - Paraiso\n#smoothjazz #nola #newyork #losangeles #miami #london #paris #montecarlo https://t.co/n5Os7ee1Tt'},
#   {'id': '1565705381531115521',
#    'author_id': '38053583',
#    'geo': {'coordinates': {'type': 'Point',
#      'coordinates': [-0.1277583, 51.5073509]},
#     'place_id': '457b4814b4240d87'},
#    'lang': 'en',
#    'created_at': '2022-09-02T14:17:07.000Z',
#    'source': 'CareerArc 2.0',
#    'text': 'Can you recommend anyone for this #Healthcare job in #London, England? Click the link in our bio to see it and more. X-Ray Screener at UPS'},
#   {'id': '1565705378150883330',
#    'author_id': '969230411128647680',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:17:06.000Z',
#    'source': 'RajputPy',
#    'text': 'Planner for success - Pink Mamm̗a Planners For Your Office and home ✋\n\n👉👉https://t.co/zyRptk5r9R\n\n#london #trips #voyage #justice4cameronherrin #cameronherrin #nomore #tplfatrocities #dubai https://t.co/NDYRiQNw80'},
#   {'id': '1565705326137163777',
#    'author_id': '239111750',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:16:53.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @BlueOctopus: Facilities Management firm @ArcusFM are seeking an experienced M&amp;E Engineer to join them in South West #London.  \n\n#engine…'},
#   {'id': '1565705290644865027',
#    'author_id': '1522696787936616448',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:16:45.000Z',
#    'source': 'Twitter Web App',
#    'text': 'September tickets are available, with EARY BIRD DISCOUNTS!🥳\n\nCode is Law -V- Code &amp; Law — Stacks End of Summer After Party!👨\u200d💻⚖️\n\n21.09.2022\n\nhttps://t.co/ehYOyzQrWb\n\n#Bitcoin #Stacks #STX #BTC #SmartContracts #Law #Blockchain #cryptocurrency #London #STXLDN'},
#   {'id': '1565705229814976515',
#    'author_id': '738090938292174851',
#    'lang': 'en',
#    'created_at': '2022-09-02T14:16:30.000Z',
#    'source': 'Twitter for iPhone',
#    'text': 'RT @ProMistressesUK: Dominica de Sin of #London has updated her profile. Check it out via https://t.co/Gl5ODcS9eT @Dominicadesin'}],
#  'meta': {'newest_id': '1565709990190632960',
#   'oldest_id': '1565705229814976515',
#   'result_count': 100,
#   'next_token': 'b26v89c19zqg8o3fpz8m05ekaehv1m4qkxydnf6irq35p'}}
