# %%
import tweepy
import json
import requests
import datetime as dt
from nltk.corpus import stopwords # stopword examples, 'its', 'on', 'the', etc <---- will be helpful later
# most pythonistas will rename pandas as pd and numpy as np for short (you don't have to)
import pandas as pd
import numpy as np

# %%
# open file with keys and set the path to your credentials JSON file
# see example.json for formatting
# you'll need to replace my file with yours
credentials = "keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
# read the keys and assign each to a variable
bearer_token = api_tokens["bearer_token"]
api_key = api_tokens["api_key"]
api_secret = api_tokens["api_secret"]
access_token = api_tokens["access_token"]
access_secret = api_tokens["access_secret"]

# %%
client = tweepy.Client(
    bearer_token=bearer_token,
    consumer_key=api_key,
    consumer_secret=api_secret,
    access_token=access_token,
    access_token_secret=access_secret,
    return_type = requests.Response
)

# %% [markdown]
# Let's look up the 100 most recent tweets using #London
# <br/>We're going to use the search_recent_tweets() function and 5 parameters, they are:
# <br/><b>q: </b>Short for query, <a href="https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query">learn more about building queries here</a>
# <br/><b>max_results: </b>The maximum number of search results to be returned by a request. A number between 10 and 100. By default, a request response will return 10 results.
# <br/><b>tweet_fields: </b><a href="https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/tweet">See all tweet fields here</a>
# <br/><b>user_fields: </b><a href="https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/user">See all user fields here</a>
# <br/><b>expansions: </b>This field will allow us to include the user_field values. <a href="https://docs.tweepy.org/en/latest/expansions_and_fields.html">Learn more about expansions here</a>

# %%
tweets = client.search_recent_tweets(
    query = "#WPP -is:retweet",  # searches for #London while ignoring retweets
    max_results = 100,
    tweet_fields = ['author_id', 'created_at', 'text', 'source', 'lang', 'geo'],
    user_fields = ['name','username','location','verified'],
    expansions = 'author_id'
)

# %%
tweets_dict = tweets.json()

# %%
tweets_dict
# Out:
# {'data': [{'id': '1565738244372803585',
#    'source': 'Tickeron',
#    'text': '$WPP enters a Downtrend as Momentum Indicator dropped below the 0 level on August 5, 2022. View odds for this and other indicators: https://t.co/gvq6YHFMzw #WPP https://t.co/a9MufN6mLe',
#    'created_at': '2022-09-02T16:27:42.000Z',
#    'lang': 'en',
#    'author_id': '374729426'},
#   {'id': '1565514952877686784',
#    'source': 'Twitter Web App',
#    'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg7QQw',
#    'created_at': '2022-09-02T01:40:25.000Z',
#    'lang': 'en',
#    'author_id': '1434909340205465605'},
#   {'id': '1565476711071973378',
#    'source': 'Twitter for iPhone',
#    'text': '@GiDavidswright Ay yo las amo, tengo botas y pilotos de cuando viví en 🇬🇧 y odio no poder usarlas tanto acá 😒 #wpp del año. Ya lo sé',
#    'created_at': '2022-09-01T23:08:27.000Z',
#    'lang': 'es',
#    'author_id': '1260946502714904576'},
#   {'id': '1565394482144587776',
#    'source': 'Tickeron',
#    'text': "$WPP's in Downtrend: Moving Average Convergence Divergence (MACD) Histogram just turned negative. View odds for this and other indicators: https://t.co/QEs6D1KBNm #WPP https://t.co/ZstH8Xgzcv",
#    'created_at': '2022-09-01T17:41:42.000Z',
#    'lang': 'en',
#    'author_id': '374729426'},
#   {'id': '1565331598324940802',
#    'source': 'Investor Feed',
#    'text': '$WPP  6-K  WPP   (1 Sep, 9:30am)\n\n📰 Total Voting Rights and Capital\n\nhttps://t.co/spfvpVc9bV\n\n#WPP #6K #News',
#    'created_at': '2022-09-01T13:31:50.000Z',
#    'lang': 'en',
#    'author_id': '1171873456276889600'},
#   {'id': '1565326212293091329',
#    'source': 'Hootsuite Inc.',
#    'text': '@WPP Acquires Ecommerce Consultancy Newcraft https://t.co/746HsVXeZv #martech #marketing #Technology #WPP #ecommerce',
#    'created_at': '2022-09-01T13:10:26.000Z',
#    'lang': 'en',
#    'author_id': '799226790065508352'},
#   {'id': '1565311917236912130',
#    'source': 'Twitter for Android',
#    'text': '@JLD_200 #WPP\nhttps://t.co/cM0OVS2RtT',
#    'created_at': '2022-09-01T12:13:37.000Z',
#    'lang': 'qme',
#    'author_id': '1340919529166221313'},
#   {'id': '1565291466947182598',
#    'source': 'Twitter Web App',
#    'text': '#WPP anuncia la adquisición de Newcraft\nhttps://t.co/BM8kpWsq82',
#    'created_at': '2022-09-01T10:52:22.000Z',
#    'lang': 'es',
#    'author_id': '114739070'},
#   {'id': '1565283732222644224',
#    'source': 'Edgar Filings',
#    'text': 'SEC Form 6-K  filed by  $WPP $WPPGF #WPP plc  https://t.co/L4bHBRisy9',
#    'created_at': '2022-09-01T10:21:37.000Z',
#    'lang': 'en',
#    'author_id': '1068561714055012352'},
#   {'id': '1565281015643492352',
#    'source': 'Investor Feed',
#    'text': '$WPP  6-K  WPP   (1 Sep, 6:08am)\n\n📰 Current report (foreign)\n\nhttps://t.co/xUkLrFmwKj\n\n#WPP #6K #News',
#    'created_at': '2022-09-01T10:10:50.000Z',
#    'lang': 'en',
#    'author_id': '1171873456276889600'},
#   {'id': '1565278011754221570',
#    'source': 'Twitter Web App',
#    'text': '📣 We’re delighted to welcome Newcraft to the WT family! \n.\nFind out more here 🔗:  https://t.co/fGf6kSauA4\n.\n#WunThompson #WPP #NEWCRAFT https://t.co/8hQrBwT1IL',
#    'created_at': '2022-09-01T09:58:54.000Z',
#    'lang': 'en',
#    'author_id': '54319874'},
#   {'id': '1565277293651677184',
#    'source': 'Proactive Investors',
#    'text': '$WPP WPP to buy European ecommerce consultancy Newcraft for undisclosed sum https://t.co/Je2dou6a9U #WPP',
#    'created_at': '2022-09-01T09:56:02.000Z',
#    'lang': 'en',
#    'author_id': '22779605'},
#   {'id': '1565256760365125632',
#    'source': 'SwingTradeBot UK',
#    'text': 'New 52 Week Low today: #SBRY #RR #BDEV #TW #TPK #LAND #BLND #GSK #LMP #SSPG #WPP #SVS #DLN #PAGE #DCC #SGRO ... https://t.co/23tMplxxq5',
#    'created_at': '2022-09-01T08:34:27.000Z',
#    'lang': 'en',
#    'author_id': '853342253804335107'},
#   {'id': '1565250895146876928',
#    'source': 'Twitter for iPad',
#    'text': 'WPP snaps up Dutch ecommerce firm Newcraft amid buoyant sales. #WPP #advertising  https://t.co/Qb5Pdg7IKM',
#    'created_at': '2022-09-01T08:11:09.000Z',
#    'lang': 'en',
#    'author_id': '953592132'},
#   {'id': '1565243385790619648',
#    'source': 'SilentTrades',
#    'text': '#WPP acquires leading data-first European ecommerce consultancy Newcraft - https://t.co/DYfazH3GsV - #Communications #Advertising #PublicRelations #Technology #eCommerce #Newcraft #FTSE100 https://t.co/Us6fU7SJo4',
#    'created_at': '2022-09-01T07:41:18.000Z',
#    'lang': 'en',
#    'author_id': '4330144943'},
#   {'id': '1565229880807247872',
#    'source': 'Twitter Web App',
#    'text': 'Good Morning\n\nUK Newsflow:\n\n#BARC-sells ABSA stake for £538m\n#CAM-Warning\n#CBOX-CEO buys shs after fall\n#GKP-Production guide reiterated\n#IXI-Exceeds previous guidance\n#JSG-Inline\n#KNOS-Inline\n#RIO-Buying rest of Turquoise Hill for $3.3b\n#WPP-Acquisition',
#    'created_at': '2022-09-01T06:47:38.000Z',
#    'lang': 'en',
#    'author_id': '1245383403454771201'},
#   {'id': '1565228542174015489',
#    'source': 'DirectorsTalk Auto Posting',
#    'text': "'#WPP acquires leading data-first European ecommerce consultancy Newcraft' \n\nLink: https://t.co/WFnWnPr2od \n\n #Communications #Advertising #PublicRelations #Technology #eCommerce #Newcraft #FTSE100 #Investing https://t.co/lJ5B8YYQwN",
#    'created_at': '2022-09-01T06:42:19.000Z',
#    'lang': 'en',
#    'author_id': '229906736'},
#   {'id': '1565222526137126915',
#    'source': 'Twitter Web App',
#    'text': '238 #RNS in One\n\nTUs 39 incl #AEX #APH #CAM #EQT #GEMD #GKP #IXI #JSG #KNOS #LOOP #MXC #NTOG #PPH #SIHL #SPO #STM #WDS #ZAIM\n\nContract Wins: #LOOP #COG #ORCP #SWG \n\nM&amp;A: #ALBA #AWE #BRH #RBD #SRP #WPP\n\nBullish/Bearish Plot👇\n\nR/T  &amp; share 🙏 https://t.co/3BZ87y9RWo',
#    'created_at': '2022-09-01T06:18:25.000Z',
#    'lang': 'en',
#    'author_id': '4833242507'},
#   {'id': '1565011514041724928',
#    'source': 'Twitter for iPhone',
#    'text': '@KatiePhang #WPP His new name is John Smith',
#    'created_at': '2022-08-31T16:19:56.000Z',
#    'lang': 'en',
#    'author_id': '1237055126281519104'},
#   {'id': '1565008272909897730',
#    'source': 'Twitter for iPhone',
#    'text': '#WPP pensando aqui se compro o iPhone 13PM sendo que é a msm coisa do meu mas eu queria tanto ele ☹️',
#    'created_at': '2022-08-31T16:07:03.000Z',
#    'lang': 'pt',
#    'author_id': '1089867996158406656'},
#   {'id': '1564996152969289732',
#    'source': 'Twitterrific for iOS',
#    'text': 'We can supply high quality, strong &amp; tear resistant #Woven #Polypropylene (#WPP) Bags, Coated #CementSacks &amp; Liners. Our bags are satisfactorily being used in various sectors like #Fertilizers, #Chemicals, #Cement, #Sugar, #Textile #PPBags #WPPBags',
#    'created_at': '2022-08-31T15:18:53.000Z',
#    'lang': 'en',
#    'author_id': '107367270'},
#   {'id': '1564995594342498305',
#    'source': 'Twitter for iPhone',
#    'geo': {'place_id': '07d9f05b02881002'},
#    'text': 'Agyam eldobom, a miskolci Freiben nem megy a klíma. Rezsit és élményt is csökkentenek. 😕☕️👎🏼\n\n#wpp #freicafe',
#    'created_at': '2022-08-31T15:16:40.000Z',
#    'lang': 'hu',
#    'author_id': '62481415'},
#   {'id': '1564988464403292162',
#    'source': 'SwingTradeBot UK',
#    'text': 'New 52 Week Low today: #ASTO #BLND #ABDN #WPP #BBOX ... https://t.co/23tMplxxq5',
#    'created_at': '2022-08-31T14:48:20.000Z',
#    'lang': 'en',
#    'author_id': '853342253804335107'},
#   {'id': '1564957689679159299',
#    'source': 'www.chartmill.com',
#    'text': '$WPP.L has an average volume of 1535710. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/0AknOYMAoA',
#    'created_at': '2022-08-31T12:46:03.000Z',
#    'lang': 'en',
#    'author_id': '121370906'},
#   {'id': '1564851941976457217',
#    'source': 'Twitter Web App',
#    'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg7QQw',
#    'created_at': '2022-08-31T05:45:51.000Z',
#    'lang': 'en',
#    'author_id': '1434909340205465605'},
#   {'id': '1564792540645060611',
#    'source': 'Tickeron',
#    'text': "$WPP's 10-day Moving Average crossed below its 50-day Moving Average on August 16, 2022. View odds for this and other indicators: https://t.co/WeLLJCDopj #WPP https://t.co/MiXPsXULsv",
#    'created_at': '2022-08-31T01:49:48.000Z',
#    'lang': 'en',
#    'author_id': '374729426'},
#   {'id': '1564656560709992450',
#    'source': 'Twitter for iPhone',
#    'text': '@B52Malmet #WPP',
#    'created_at': '2022-08-30T16:49:28.000Z',
#    'lang': 'qme',
#    'author_id': '1237055126281519104'},
#   {'id': '1564627325999800324',
#    'source': 'SwingTradeBot UK',
#    'text': 'New 52 Week Low today: #PNN #HWDN #SN #HIK #WPP ... https://t.co/23tMplxxq5',
#    'created_at': '2022-08-30T14:53:18.000Z',
#    'lang': 'en',
#    'author_id': '853342253804335107'},
#   {'id': '1564608134399787012',
#    'source': 'www.chartmill.com',
#    'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/0mhLBkyr7N',
#    'created_at': '2022-08-30T13:37:02.000Z',
#    'lang': 'en',
#    'author_id': '121370906'},
#   {'id': '1564593281522143235',
#    'source': 'Twitter Web App',
#    'text': 'This anti- fossil fuel agency campaign is clearly not going to go away... #edelman #wpp #shell #bp https://t.co/RjebrpiFBX via @prweek',
#    'created_at': '2022-08-30T12:38:01.000Z',
#    'lang': 'en',
#    'author_id': '20906444'},
#   {'id': '1564571615152717827',
#    'source': 'Twitter for Android',
#    'text': 'Gente, já aconteceu com vocês de as datas do wpp estarem erradas? Algumas conversas que aconteceram em um dia com data de outro dia? Ou até mesmo fotos aparecendo em conversas aleatórias como bug?\n#wpp #bug #VMAs #HouseoftheDragon #studytwt',
#    'created_at': '2022-08-30T11:11:56.000Z',
#    'lang': 'pt',
#    'author_id': '1372375318439288836'},
#   {'id': '1564451608171352066',
#    'source': 'www.chartmill.com',
#    'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/rEc3Q3cGtt',
#    'created_at': '2022-08-30T03:15:04.000Z',
#    'lang': 'en',
#    'author_id': '121370906'},
#   {'id': '1564443430289383424',
#    'source': 'Twitter',
#    'text': "#WPP the closest resistance level we identified is at $45.01\nhttps://t.co/7aJo4RGOi6\nTry our new intuitive free stock screener on https://t.co/HTGEXJ7Qnd - it's the best screener ever made",
#    'created_at': '2022-08-30T02:42:34.000Z',
#    'lang': 'en',
#    'author_id': '1495351200258084866'},
#   {'id': '1564362844107333635',
#    'source': 'Twitter for Android',
#    'text': '@StockRocket1 #WPP \n$BOPO',
#    'created_at': '2022-08-29T21:22:21.000Z',
#    'lang': 'pt',
#    'author_id': '1522607300950863872'},
#   {'id': '1564302942793961472',
#    'source': 'Tickeron',
#    'text': "$WPP's 10-day Moving Average broke below its 50-day Moving Average on August 16, 2022. View odds for this and other indicators: https://t.co/e2Drt3JNOa #WPP https://t.co/C1gSf6C7iM",
#    'created_at': '2022-08-29T17:24:19.000Z',
#    'lang': 'en',
#    'author_id': '374729426'},
#   {'id': '1564171443243556865',
#    'source': 'Twitter Web App',
#    'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg7QQw',
#    'created_at': '2022-08-29T08:41:47.000Z',
#    'lang': 'en',
#    'author_id': '1434909340205465605'},
#   {'id': '1564134267436912642',
#    'source': 'Twitter for Android',
#    'text': '@JLD_200 #WPP \nhttps://t.co/cM0OVS2RtT',
#    'created_at': '2022-08-29T06:14:04.000Z',
#    'lang': 'qme',
#    'author_id': '1340919529166221313'},
#   {'id': '1564124074464395264',
#    'source': 'Twitter for iPad',
#    'text': 'Spojenie #JanBinar &amp; #PetraPipkova tu uz bolo historicky a fungovalo napriek prepojeniu #IPG s #WPP… ale interne zaclenenie, ktore @hondzyk76 realizuje uspesne v McCann Prague uz roky, je vyrazny krok a pozitivna cesta.\n\n#McCannMedia\n\nhttps://t.co/SiSWjqcEMr',
#    'created_at': '2022-08-29T05:33:34.000Z',
#    'lang': 'und',
#    'author_id': '1461613387'},
#   {'id': '1563955195440160768',
#    'source': 'Twitter for iPhone',
#    'text': 'WPP Akademi podcast serisi Metaverse&amp;More pilot bölümleri ile yayına başladı! \nWeb 3.0, NFT, Blockchain gibi konu başlıkları kanaat lideri konukların katılımı ile evrenler arası bilgi akışına dönüşüyor. \n\n#WPP #WPPAcademies #MetaVerse \n\nhttps://t.co/3MnYPdeuYr',
#    'created_at': '2022-08-28T18:22:30.000Z',
#    'lang': 'tr',
#    'author_id': '81170415'},
#   {'id': '1563925877049671686',
#    'source': 'Tickeron',
#    'text': "$WPP's 10-day Moving Average crossed below its 50-day Moving Average on August 16, 2022. View odds for this and other indicators: https://t.co/pLm5XBHMR7 #WPP https://t.co/FSE2q98fxX",
#    'created_at': '2022-08-28T16:26:00.000Z',
#    'lang': 'en',
#    'author_id': '374729426'},
#   {'id': '1563825477298622468',
#    'source': 'www.chartmill.com',
#    'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/y6hioMJHQs',
#    'created_at': '2022-08-28T09:47:02.000Z',
#    'lang': 'en',
#    'author_id': '121370906'},
#   {'id': '1563594411480473600',
#    'source': 'Twitter for iPhone',
#    'text': 'uma coisa que aprendi nesse tempo sem trabalho e é não dá pra esperar ter um tempo certo pra comprar coisas que tá precisando e fica postergando sem motivo e gastando com coisas inúteis ao invés de comprar o q precisa #wpp',
#    'created_at': '2022-08-27T18:28:52.000Z',
#    'lang': 'pt',
#    'author_id': '49186493'},
#   {'id': '1563503589678465025',
#    'source': 'Twitter for iPhone',
#    'text': 'Não basta nao ter bolo de cenoura. Os caras não tem calda de chocolate no bolo de chocolate. QUE MUNDO É ESSE #WPP https://t.co/ugjaHOPY2c',
#    'created_at': '2022-08-27T12:27:58.000Z',
#    'lang': 'pt',
#    'author_id': '50665199'},
#   {'id': '1563496305296429057',
#    'source': 'Twitter for Android',
#    'text': '@kucoincom #WPP $WPP\nhttps://t.co/cM0OVRLg5j',
#    'created_at': '2022-08-27T11:59:02.000Z',
#    'lang': 'qme',
#    'author_id': '1340919529166221313'},
#   {'id': '1563452744375369729',
#    'source': 'Twitter',
#    'text': '#WPP Regarding indicators, \nhttps://t.co/7aJo4RHm7E',
#    'created_at': '2022-08-27T09:05:56.000Z',
#    'lang': 'en',
#    'author_id': '1495351200258084866'},
#   {'id': '1563449958568644608',
#    'source': 'Twitter for Android',
#    'text': 'A sinking market; #DARK saved me recently, this week #MCRO bid +94% Friday to rescue, market not pricing another bid. O&amp;G supports, but many big fallers inc; #WPP, #HIK, #REDD, #LGEN &amp; #GSK. FY revenue +69% at #S32 returns 10% of mkt cap this year. Folio for week -1.4%, YTD -2.3%',
#    'created_at': '2022-08-27T08:54:52.000Z',
#    'lang': 'en',
#    'author_id': '361829058'},
#   {'id': '1563449577591545857',
#    'source': 'Twitter for iPhone',
#    'text': 'Woohoo! #WPP https://t.co/xU1bnlsvas',
#    'created_at': '2022-08-27T08:53:21.000Z',
#    'lang': 'en',
#    'author_id': '1314739485930786818'},
#   {'id': '1563424047077400584',
#    'source': 'Twitter Web App',
#    'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg8oG4',
#    'created_at': '2022-08-27T07:11:54.000Z',
#    'lang': 'en',
#    'author_id': '1434909340205465605'},
#   {'id': '1563376310831161344',
#    'source': 'SwingTradeBot UK',
#    'text': '#WPP technical alerts: New 52 Week Low and New 52 Week Closing Low  https://t.co/z3nEwez0xP',
#    'created_at': '2022-08-27T04:02:13.000Z',
#    'lang': 'en',
#    'author_id': '853342253804335107'},
#   {'id': '1563320903366504452',
#    'source': 'www.chartmill.com',
#    'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvO4J #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/ghvTsNYcmQ',
#    'created_at': '2022-08-27T00:22:03.000Z',
#    'lang': 'en',
#    'author_id': '121370906'},
#   {'id': '1563269816362086402',
#    'source': 'www.chartmill.com',
#    'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvO4J #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/1f6N6o82lw',
#    'created_at': '2022-08-26T20:59:03.000Z',
#    'lang': 'en',
#    'author_id': '121370906'},
#   {'id': '1563233368908906496',
#    'source': 'Twitter for Android',
#    'text': 'Hola 👋👋 estamos #SORTEANDO un hermoso Mangrullo RústicosBell 🤯\nSe viene el verano ,ideal para regalo o para sus niños 🌞🎉\nProva tu suerte con RústicosBell 😁 Empresa Familiar dedicada a lo Rústico 💓 #wpp-#catalogo 1125036665! Números Disponibles! Solo Bs As. https://t.co/OoH8jXKJ2J',
#    'created_at': '2022-08-26T18:34:13.000Z',
#    'lang': 'es',
#    'author_id': '1559673867098095616'}],
#  'includes': {'users': [{'id': '374729426',
#     'verified': False,
#     'username': 'Tickeron',
#     'location': 'Sunnyvale, CA',
#     'name': 'Tickeron'},
#    {'id': '1434909340205465605',
#     'verified': False,
#     'username': 'SuccessAfter25',
#     'name': 'Trader PLUS'},
#    {'id': '1260946502714904576',
#     'verified': False,
#     'username': 'lahannadom',
#     'location': 'Buenos Aires, Argentina',
#     'name': 'Anto'},
#    {'id': '1171873456276889600',
#     'verified': False,
#     'username': 'investor_feed',
#     'location': 'Toronto, Canada',
#     'name': 'Docoh Feed'},
#    {'id': '799226790065508352',
#     'verified': False,
#     'username': 'MarTechSeries',
#     'location': 'Hawthorne, CA',
#     'name': 'MarTech Series'},
#    {'id': '1340919529166221313',
#     'verified': False,
#     'username': 'TZokani',
#     'name': 'Tarek Zokani'},
#    {'id': '114739070',
#     'verified': False,
#     'username': 'PdelaPublicidad',
#     'location': 'Madrid, Spain',
#     'name': 'Periódico PublicidAD'},
#    {'id': '1068561714055012352',
#     'verified': False,
#     'username': 'EdgarInsider',
#     'name': 'SEC.report'},
#    {'id': '54319874',
#     'verified': True,
#     'username': 'WunThompson',
#     'location': 'Global',
#     'name': 'Wunderman Thompson'},
#    {'id': '22779605',
#     'verified': False,
#     'username': 'proactive_UK',
#     'location': 'London, England',
#     'name': 'Proactive'},
#    {'id': '853342253804335107',
#     'verified': False,
#     'username': 'SwingTradeBotUK',
#     'location': 'London, England',
#     'name': 'SwingTradeBot UK'},
#    {'id': '953592132',
#     'verified': False,
#     'username': 'andrewsduncan1',
#     'location': 'London. United Kingdom',
#     'name': 'Andrew Duncan'},
#    {'id': '4330144943',
#     'verified': False,
#     'username': 'silent_trades',
#     'name': 'Francis Alexander'},
#    {'id': '1245383403454771201',
#     'verified': False,
#     'username': 'andrewdc208',
#     'location': 'London, England',
#     'name': 'Andrewdc208'},
#    {'id': '229906736',
#     'verified': False,
#     'username': 'DirectorsTalk',
#     'name': 'DirectorsTalk'},
#    {'id': '4833242507',
#     'verified': False,
#     'username': 'runningprofits',
#     'location': 'United Kingdom',
#     'name': 'donncha @ runprofits.com'},
#    {'id': '1237055126281519104',
#     'verified': False,
#     'username': 'JRogers40817410',
#     'name': 'J Rogers'},
#    {'id': '1089867996158406656',
#     'verified': False,
#     'username': 'eumexmo99',
#     'location': 'Campinas, Brasil',
#     'name': 'minhapedraamestiça💎'},
#    {'id': '107367270',
#     'verified': False,
#     'username': 'RasheedMemon',
#     'location': 'Dubai, United Arab Emirates',
#     'name': '𝕽𝖆𝖘𝖍𝖊𝖊𝖉'},
#    {'id': '62481415',
#     'verified': False,
#     'username': 'gabormatesz',
#     'location': 'Miskolc, Hungary',
#     'name': '𝙶𝚊𝚋𝚘𝚛'},
#    {'id': '121370906',
#     'verified': False,
#     'username': 'ChartMill',
#     'location': 'Belgium',
#     'name': 'ChartMill'},
#    {'id': '20906444',
#     'verified': False,
#     'username': 'dannyrogers2001',
#     'location': 'London, England',
#     'name': 'Danny Rogers'},
#    {'id': '1372375318439288836',
#     'verified': False,
#     'username': 'itsmoizinho',
#     'location': 'Campina Grande, Brasil',
#     'name': 'Its Moizinho 🌻'},
#    {'id': '1495351200258084866',
#     'verified': False,
#     'username': 'stockosaur_com',
#     'name': 'stockosaur.com'},
#    {'id': '1522607300950863872',
#     'verified': False,
#     'username': 'bab_twins',
#     'name': 'Twins Bab'},
#    {'id': '1461613387',
#     'verified': False,
#     'username': 'PavolMacinga',
#     'location': 'Czech & Slovakia',
#     'name': 'Pavol Mačinga'},
#    {'id': '81170415',
#     'verified': False,
#     'username': 'effectbcw',
#     'location': 'Istanbul, Turkey',
#     'name': 'effect bcw'},
#    {'id': '49186493',
#     'verified': False,
#     'username': 'amandabrbz',
#     'location': 'Curitiba',
#     'name': 'Amanda'},
#    {'id': '50665199',
#     'verified': False,
#     'username': 'larigouveia',
#     'name': 'lari ruiva'},
#    {'id': '361829058',
#     'verified': False,
#     'username': 'SandyMidd',
#     'location': 'London, UK',
#     'name': 'Sandy'},
#    {'id': '1314739485930786818',
#     'verified': False,
#     'username': 'ElvitaNatassa',
#     'location': 'Bali, Indonesia',
#     'name': 'Brown Sugar Bali'},
#    {'id': '1559673867098095616',
#     'verified': False,
#     'username': 'RusticosBell',
#     'location': 'Moreno, Argentina',
#     'name': 'RústicosBell 🤯'}]},
#  'meta': {'newest_id': '1565738244372803585',
#   'oldest_id': '1563233368908906496',
#   'result_count': 52}}

# %%
# extract 'data' from dictionary, this will exclude the metadata
tweets_data = tweets_dict['data']
tweets_users = tweets_dict['includes']['users']

# %%
tweets_data
# Out:
# [{'id': '1565738244372803585',
#   'source': 'Tickeron',
#   'text': '$WPP enters a Downtrend as Momentum Indicator dropped below the 0 level on August 5, 2022. View odds for this and other indicators: https://t.co/gvq6YHFMzw #WPP https://t.co/a9MufN6mLe',
#   'created_at': '2022-09-02T16:27:42.000Z',
#   'lang': 'en',
#   'author_id': '374729426'},
#  {'id': '1565514952877686784',
#   'source': 'Twitter Web App',
#   'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg7QQw',
#   'created_at': '2022-09-02T01:40:25.000Z',
#   'lang': 'en',
#   'author_id': '1434909340205465605'},
#  {'id': '1565476711071973378',
#   'source': 'Twitter for iPhone',
#   'text': '@GiDavidswright Ay yo las amo, tengo botas y pilotos de cuando viví en 🇬🇧 y odio no poder usarlas tanto acá 😒 #wpp del año. Ya lo sé',
#   'created_at': '2022-09-01T23:08:27.000Z',
#   'lang': 'es',
#   'author_id': '1260946502714904576'},
#  {'id': '1565394482144587776',
#   'source': 'Tickeron',
#   'text': "$WPP's in Downtrend: Moving Average Convergence Divergence (MACD) Histogram just turned negative. View odds for this and other indicators: https://t.co/QEs6D1KBNm #WPP https://t.co/ZstH8Xgzcv",
#   'created_at': '2022-09-01T17:41:42.000Z',
#   'lang': 'en',
#   'author_id': '374729426'},
#  {'id': '1565331598324940802',
#   'source': 'Investor Feed',
#   'text': '$WPP  6-K  WPP   (1 Sep, 9:30am)\n\n📰 Total Voting Rights and Capital\n\nhttps://t.co/spfvpVc9bV\n\n#WPP #6K #News',
#   'created_at': '2022-09-01T13:31:50.000Z',
#   'lang': 'en',
#   'author_id': '1171873456276889600'},
#  {'id': '1565326212293091329',
#   'source': 'Hootsuite Inc.',
#   'text': '@WPP Acquires Ecommerce Consultancy Newcraft https://t.co/746HsVXeZv #martech #marketing #Technology #WPP #ecommerce',
#   'created_at': '2022-09-01T13:10:26.000Z',
#   'lang': 'en',
#   'author_id': '799226790065508352'},
#  {'id': '1565311917236912130',
#   'source': 'Twitter for Android',
#   'text': '@JLD_200 #WPP\nhttps://t.co/cM0OVS2RtT',
#   'created_at': '2022-09-01T12:13:37.000Z',
#   'lang': 'qme',
#   'author_id': '1340919529166221313'},
#  {'id': '1565291466947182598',
#   'source': 'Twitter Web App',
#   'text': '#WPP anuncia la adquisición de Newcraft\nhttps://t.co/BM8kpWsq82',
#   'created_at': '2022-09-01T10:52:22.000Z',
#   'lang': 'es',
#   'author_id': '114739070'},
#  {'id': '1565283732222644224',
#   'source': 'Edgar Filings',
#   'text': 'SEC Form 6-K  filed by  $WPP $WPPGF #WPP plc  https://t.co/L4bHBRisy9',
#   'created_at': '2022-09-01T10:21:37.000Z',
#   'lang': 'en',
#   'author_id': '1068561714055012352'},
#  {'id': '1565281015643492352',
#   'source': 'Investor Feed',
#   'text': '$WPP  6-K  WPP   (1 Sep, 6:08am)\n\n📰 Current report (foreign)\n\nhttps://t.co/xUkLrFmwKj\n\n#WPP #6K #News',
#   'created_at': '2022-09-01T10:10:50.000Z',
#   'lang': 'en',
#   'author_id': '1171873456276889600'},
#  {'id': '1565278011754221570',
#   'source': 'Twitter Web App',
#   'text': '📣 We’re delighted to welcome Newcraft to the WT family! \n.\nFind out more here 🔗:  https://t.co/fGf6kSauA4\n.\n#WunThompson #WPP #NEWCRAFT https://t.co/8hQrBwT1IL',
#   'created_at': '2022-09-01T09:58:54.000Z',
#   'lang': 'en',
#   'author_id': '54319874'},
#  {'id': '1565277293651677184',
#   'source': 'Proactive Investors',
#   'text': '$WPP WPP to buy European ecommerce consultancy Newcraft for undisclosed sum https://t.co/Je2dou6a9U #WPP',
#   'created_at': '2022-09-01T09:56:02.000Z',
#   'lang': 'en',
#   'author_id': '22779605'},
#  {'id': '1565256760365125632',
#   'source': 'SwingTradeBot UK',
#   'text': 'New 52 Week Low today: #SBRY #RR #BDEV #TW #TPK #LAND #BLND #GSK #LMP #SSPG #WPP #SVS #DLN #PAGE #DCC #SGRO ... https://t.co/23tMplxxq5',
#   'created_at': '2022-09-01T08:34:27.000Z',
#   'lang': 'en',
#   'author_id': '853342253804335107'},
#  {'id': '1565250895146876928',
#   'source': 'Twitter for iPad',
#   'text': 'WPP snaps up Dutch ecommerce firm Newcraft amid buoyant sales. #WPP #advertising  https://t.co/Qb5Pdg7IKM',
#   'created_at': '2022-09-01T08:11:09.000Z',
#   'lang': 'en',
#   'author_id': '953592132'},
#  {'id': '1565243385790619648',
#   'source': 'SilentTrades',
#   'text': '#WPP acquires leading data-first European ecommerce consultancy Newcraft - https://t.co/DYfazH3GsV - #Communications #Advertising #PublicRelations #Technology #eCommerce #Newcraft #FTSE100 https://t.co/Us6fU7SJo4',
#   'created_at': '2022-09-01T07:41:18.000Z',
#   'lang': 'en',
#   'author_id': '4330144943'},
#  {'id': '1565229880807247872',
#   'source': 'Twitter Web App',
#   'text': 'Good Morning\n\nUK Newsflow:\n\n#BARC-sells ABSA stake for £538m\n#CAM-Warning\n#CBOX-CEO buys shs after fall\n#GKP-Production guide reiterated\n#IXI-Exceeds previous guidance\n#JSG-Inline\n#KNOS-Inline\n#RIO-Buying rest of Turquoise Hill for $3.3b\n#WPP-Acquisition',
#   'created_at': '2022-09-01T06:47:38.000Z',
#   'lang': 'en',
#   'author_id': '1245383403454771201'},
#  {'id': '1565228542174015489',
#   'source': 'DirectorsTalk Auto Posting',
#   'text': "'#WPP acquires leading data-first European ecommerce consultancy Newcraft' \n\nLink: https://t.co/WFnWnPr2od \n\n #Communications #Advertising #PublicRelations #Technology #eCommerce #Newcraft #FTSE100 #Investing https://t.co/lJ5B8YYQwN",
#   'created_at': '2022-09-01T06:42:19.000Z',
#   'lang': 'en',
#   'author_id': '229906736'},
#  {'id': '1565222526137126915',
#   'source': 'Twitter Web App',
#   'text': '238 #RNS in One\n\nTUs 39 incl #AEX #APH #CAM #EQT #GEMD #GKP #IXI #JSG #KNOS #LOOP #MXC #NTOG #PPH #SIHL #SPO #STM #WDS #ZAIM\n\nContract Wins: #LOOP #COG #ORCP #SWG \n\nM&amp;A: #ALBA #AWE #BRH #RBD #SRP #WPP\n\nBullish/Bearish Plot👇\n\nR/T  &amp; share 🙏 https://t.co/3BZ87y9RWo',
#   'created_at': '2022-09-01T06:18:25.000Z',
#   'lang': 'en',
#   'author_id': '4833242507'},
#  {'id': '1565011514041724928',
#   'source': 'Twitter for iPhone',
#   'text': '@KatiePhang #WPP His new name is John Smith',
#   'created_at': '2022-08-31T16:19:56.000Z',
#   'lang': 'en',
#   'author_id': '1237055126281519104'},
#  {'id': '1565008272909897730',
#   'source': 'Twitter for iPhone',
#   'text': '#WPP pensando aqui se compro o iPhone 13PM sendo que é a msm coisa do meu mas eu queria tanto ele ☹️',
#   'created_at': '2022-08-31T16:07:03.000Z',
#   'lang': 'pt',
#   'author_id': '1089867996158406656'},
#  {'id': '1564996152969289732',
#   'source': 'Twitterrific for iOS',
#   'text': 'We can supply high quality, strong &amp; tear resistant #Woven #Polypropylene (#WPP) Bags, Coated #CementSacks &amp; Liners. Our bags are satisfactorily being used in various sectors like #Fertilizers, #Chemicals, #Cement, #Sugar, #Textile #PPBags #WPPBags',
#   'created_at': '2022-08-31T15:18:53.000Z',
#   'lang': 'en',
#   'author_id': '107367270'},
#  {'id': '1564995594342498305',
#   'source': 'Twitter for iPhone',
#   'geo': {'place_id': '07d9f05b02881002'},
#   'text': 'Agyam eldobom, a miskolci Freiben nem megy a klíma. Rezsit és élményt is csökkentenek. 😕☕️👎🏼\n\n#wpp #freicafe',
#   'created_at': '2022-08-31T15:16:40.000Z',
#   'lang': 'hu',
#   'author_id': '62481415'},
#  {'id': '1564988464403292162',
#   'source': 'SwingTradeBot UK',
#   'text': 'New 52 Week Low today: #ASTO #BLND #ABDN #WPP #BBOX ... https://t.co/23tMplxxq5',
#   'created_at': '2022-08-31T14:48:20.000Z',
#   'lang': 'en',
#   'author_id': '853342253804335107'},
#  {'id': '1564957689679159299',
#   'source': 'www.chartmill.com',
#   'text': '$WPP.L has an average volume of 1535710. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/0AknOYMAoA',
#   'created_at': '2022-08-31T12:46:03.000Z',
#   'lang': 'en',
#   'author_id': '121370906'},
#  {'id': '1564851941976457217',
#   'source': 'Twitter Web App',
#   'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg7QQw',
#   'created_at': '2022-08-31T05:45:51.000Z',
#   'lang': 'en',
#   'author_id': '1434909340205465605'},
#  {'id': '1564792540645060611',
#   'source': 'Tickeron',
#   'text': "$WPP's 10-day Moving Average crossed below its 50-day Moving Average on August 16, 2022. View odds for this and other indicators: https://t.co/WeLLJCDopj #WPP https://t.co/MiXPsXULsv",
#   'created_at': '2022-08-31T01:49:48.000Z',
#   'lang': 'en',
#   'author_id': '374729426'},
#  {'id': '1564656560709992450',
#   'source': 'Twitter for iPhone',
#   'text': '@B52Malmet #WPP',
#   'created_at': '2022-08-30T16:49:28.000Z',
#   'lang': 'qme',
#   'author_id': '1237055126281519104'},
#  {'id': '1564627325999800324',
#   'source': 'SwingTradeBot UK',
#   'text': 'New 52 Week Low today: #PNN #HWDN #SN #HIK #WPP ... https://t.co/23tMplxxq5',
#   'created_at': '2022-08-30T14:53:18.000Z',
#   'lang': 'en',
#   'author_id': '853342253804335107'},
#  {'id': '1564608134399787012',
#   'source': 'www.chartmill.com',
#   'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/0mhLBkyr7N',
#   'created_at': '2022-08-30T13:37:02.000Z',
#   'lang': 'en',
#   'author_id': '121370906'},
#  {'id': '1564593281522143235',
#   'source': 'Twitter Web App',
#   'text': 'This anti- fossil fuel agency campaign is clearly not going to go away... #edelman #wpp #shell #bp https://t.co/RjebrpiFBX via @prweek',
#   'created_at': '2022-08-30T12:38:01.000Z',
#   'lang': 'en',
#   'author_id': '20906444'},
#  {'id': '1564571615152717827',
#   'source': 'Twitter for Android',
#   'text': 'Gente, já aconteceu com vocês de as datas do wpp estarem erradas? Algumas conversas que aconteceram em um dia com data de outro dia? Ou até mesmo fotos aparecendo em conversas aleatórias como bug?\n#wpp #bug #VMAs #HouseoftheDragon #studytwt',
#   'created_at': '2022-08-30T11:11:56.000Z',
#   'lang': 'pt',
#   'author_id': '1372375318439288836'},
#  {'id': '1564451608171352066',
#   'source': 'www.chartmill.com',
#   'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/rEc3Q3cGtt',
#   'created_at': '2022-08-30T03:15:04.000Z',
#   'lang': 'en',
#   'author_id': '121370906'},
#  {'id': '1564443430289383424',
#   'source': 'Twitter',
#   'text': "#WPP the closest resistance level we identified is at $45.01\nhttps://t.co/7aJo4RGOi6\nTry our new intuitive free stock screener on https://t.co/HTGEXJ7Qnd - it's the best screener ever made",
#   'created_at': '2022-08-30T02:42:34.000Z',
#   'lang': 'en',
#   'author_id': '1495351200258084866'},
#  {'id': '1564362844107333635',
#   'source': 'Twitter for Android',
#   'text': '@StockRocket1 #WPP \n$BOPO',
#   'created_at': '2022-08-29T21:22:21.000Z',
#   'lang': 'pt',
#   'author_id': '1522607300950863872'},
#  {'id': '1564302942793961472',
#   'source': 'Tickeron',
#   'text': "$WPP's 10-day Moving Average broke below its 50-day Moving Average on August 16, 2022. View odds for this and other indicators: https://t.co/e2Drt3JNOa #WPP https://t.co/C1gSf6C7iM",
#   'created_at': '2022-08-29T17:24:19.000Z',
#   'lang': 'en',
#   'author_id': '374729426'},
#  {'id': '1564171443243556865',
#   'source': 'Twitter Web App',
#   'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg7QQw',
#   'created_at': '2022-08-29T08:41:47.000Z',
#   'lang': 'en',
#   'author_id': '1434909340205465605'},
#  {'id': '1564134267436912642',
#   'source': 'Twitter for Android',
#   'text': '@JLD_200 #WPP \nhttps://t.co/cM0OVS2RtT',
#   'created_at': '2022-08-29T06:14:04.000Z',
#   'lang': 'qme',
#   'author_id': '1340919529166221313'},
#  {'id': '1564124074464395264',
#   'source': 'Twitter for iPad',
#   'text': 'Spojenie #JanBinar &amp; #PetraPipkova tu uz bolo historicky a fungovalo napriek prepojeniu #IPG s #WPP… ale interne zaclenenie, ktore @hondzyk76 realizuje uspesne v McCann Prague uz roky, je vyrazny krok a pozitivna cesta.\n\n#McCannMedia\n\nhttps://t.co/SiSWjqcEMr',
#   'created_at': '2022-08-29T05:33:34.000Z',
#   'lang': 'und',
#   'author_id': '1461613387'},
#  {'id': '1563955195440160768',
#   'source': 'Twitter for iPhone',
#   'text': 'WPP Akademi podcast serisi Metaverse&amp;More pilot bölümleri ile yayına başladı! \nWeb 3.0, NFT, Blockchain gibi konu başlıkları kanaat lideri konukların katılımı ile evrenler arası bilgi akışına dönüşüyor. \n\n#WPP #WPPAcademies #MetaVerse \n\nhttps://t.co/3MnYPdeuYr',
#   'created_at': '2022-08-28T18:22:30.000Z',
#   'lang': 'tr',
#   'author_id': '81170415'},
#  {'id': '1563925877049671686',
#   'source': 'Tickeron',
#   'text': "$WPP's 10-day Moving Average crossed below its 50-day Moving Average on August 16, 2022. View odds for this and other indicators: https://t.co/pLm5XBHMR7 #WPP https://t.co/FSE2q98fxX",
#   'created_at': '2022-08-28T16:26:00.000Z',
#   'lang': 'en',
#   'author_id': '374729426'},
#  {'id': '1563825477298622468',
#   'source': 'www.chartmill.com',
#   'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvgfb #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/y6hioMJHQs',
#   'created_at': '2022-08-28T09:47:02.000Z',
#   'lang': 'en',
#   'author_id': '121370906'},
#  {'id': '1563594411480473600',
#   'source': 'Twitter for iPhone',
#   'text': 'uma coisa que aprendi nesse tempo sem trabalho e é não dá pra esperar ter um tempo certo pra comprar coisas que tá precisando e fica postergando sem motivo e gastando com coisas inúteis ao invés de comprar o q precisa #wpp',
#   'created_at': '2022-08-27T18:28:52.000Z',
#   'lang': 'pt',
#   'author_id': '49186493'},
#  {'id': '1563503589678465025',
#   'source': 'Twitter for iPhone',
#   'text': 'Não basta nao ter bolo de cenoura. Os caras não tem calda de chocolate no bolo de chocolate. QUE MUNDO É ESSE #WPP https://t.co/ugjaHOPY2c',
#   'created_at': '2022-08-27T12:27:58.000Z',
#   'lang': 'pt',
#   'author_id': '50665199'},
#  {'id': '1563496305296429057',
#   'source': 'Twitter for Android',
#   'text': '@kucoincom #WPP $WPP\nhttps://t.co/cM0OVRLg5j',
#   'created_at': '2022-08-27T11:59:02.000Z',
#   'lang': 'qme',
#   'author_id': '1340919529166221313'},
#  {'id': '1563452744375369729',
#   'source': 'Twitter',
#   'text': '#WPP Regarding indicators, \nhttps://t.co/7aJo4RHm7E',
#   'created_at': '2022-08-27T09:05:56.000Z',
#   'lang': 'en',
#   'author_id': '1495351200258084866'},
#  {'id': '1563449958568644608',
#   'source': 'Twitter for Android',
#   'text': 'A sinking market; #DARK saved me recently, this week #MCRO bid +94% Friday to rescue, market not pricing another bid. O&amp;G supports, but many big fallers inc; #WPP, #HIK, #REDD, #LGEN &amp; #GSK. FY revenue +69% at #S32 returns 10% of mkt cap this year. Folio for week -1.4%, YTD -2.3%',
#   'created_at': '2022-08-27T08:54:52.000Z',
#   'lang': 'en',
#   'author_id': '361829058'},
#  {'id': '1563449577591545857',
#   'source': 'Twitter for iPhone',
#   'text': 'Woohoo! #WPP https://t.co/xU1bnlsvas',
#   'created_at': '2022-08-27T08:53:21.000Z',
#   'lang': 'en',
#   'author_id': '1314739485930786818'},
#  {'id': '1563424047077400584',
#   'source': 'Twitter Web App',
#   'text': '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members for making huge gains with Trade Ideas $WPP #WPP \n\nhttps://t.co/rEobNg8oG4',
#   'created_at': '2022-08-27T07:11:54.000Z',
#   'lang': 'en',
#   'author_id': '1434909340205465605'},
#  {'id': '1563376310831161344',
#   'source': 'SwingTradeBot UK',
#   'text': '#WPP technical alerts: New 52 Week Low and New 52 Week Closing Low  https://t.co/z3nEwez0xP',
#   'created_at': '2022-08-27T04:02:13.000Z',
#   'lang': 'en',
#   'author_id': '853342253804335107'},
#  {'id': '1563320903366504452',
#   'source': 'www.chartmill.com',
#   'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvO4J #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/ghvTsNYcmQ',
#   'created_at': '2022-08-27T00:22:03.000Z',
#   'lang': 'en',
#   'author_id': '121370906'},
#  {'id': '1563269816362086402',
#   'source': 'www.chartmill.com',
#   'text': '$WPP.L has an average volume of 1518070. This is a good sign as it is always nice to have a liquid stock. https://t.co/qvwDnsvO4J #ChartMill #WPPPLC #WPP #LondonStockExchange #TechnicalAnalysis https://t.co/1f6N6o82lw',
#   'created_at': '2022-08-26T20:59:03.000Z',
#   'lang': 'en',
#   'author_id': '121370906'},
#  {'id': '1563233368908906496',
#   'source': 'Twitter for Android',
#   'text': 'Hola 👋👋 estamos #SORTEANDO un hermoso Mangrullo RústicosBell 🤯\nSe viene el verano ,ideal para regalo o para sus niños 🌞🎉\nProva tu suerte con RústicosBell 😁 Empresa Familiar dedicada a lo Rústico 💓 #wpp-#catalogo 1125036665! Números Disponibles! Solo Bs As. https://t.co/OoH8jXKJ2J',
#   'created_at': '2022-08-26T18:34:13.000Z',
#   'lang': 'es',
#   'author_id': '1559673867098095616'}]

# %%
tweets_users
# Out:
# [{'id': '374729426',
#   'verified': False,
#   'username': 'Tickeron',
#   'location': 'Sunnyvale, CA',
#   'name': 'Tickeron'},
#  {'id': '1434909340205465605',
#   'verified': False,
#   'username': 'SuccessAfter25',
#   'name': 'Trader PLUS'},
#  {'id': '1260946502714904576',
#   'verified': False,
#   'username': 'lahannadom',
#   'location': 'Buenos Aires, Argentina',
#   'name': 'Anto'},
#  {'id': '1171873456276889600',
#   'verified': False,
#   'username': 'investor_feed',
#   'location': 'Toronto, Canada',
#   'name': 'Docoh Feed'},
#  {'id': '799226790065508352',
#   'verified': False,
#   'username': 'MarTechSeries',
#   'location': 'Hawthorne, CA',
#   'name': 'MarTech Series'},
#  {'id': '1340919529166221313',
#   'verified': False,
#   'username': 'TZokani',
#   'name': 'Tarek Zokani'},
#  {'id': '114739070',
#   'verified': False,
#   'username': 'PdelaPublicidad',
#   'location': 'Madrid, Spain',
#   'name': 'Periódico PublicidAD'},
#  {'id': '1068561714055012352',
#   'verified': False,
#   'username': 'EdgarInsider',
#   'name': 'SEC.report'},
#  {'id': '54319874',
#   'verified': True,
#   'username': 'WunThompson',
#   'location': 'Global',
#   'name': 'Wunderman Thompson'},
#  {'id': '22779605',
#   'verified': False,
#   'username': 'proactive_UK',
#   'location': 'London, England',
#   'name': 'Proactive'},
#  {'id': '853342253804335107',
#   'verified': False,
#   'username': 'SwingTradeBotUK',
#   'location': 'London, England',
#   'name': 'SwingTradeBot UK'},
#  {'id': '953592132',
#   'verified': False,
#   'username': 'andrewsduncan1',
#   'location': 'London. United Kingdom',
#   'name': 'Andrew Duncan'},
#  {'id': '4330144943',
#   'verified': False,
#   'username': 'silent_trades',
#   'name': 'Francis Alexander'},
#  {'id': '1245383403454771201',
#   'verified': False,
#   'username': 'andrewdc208',
#   'location': 'London, England',
#   'name': 'Andrewdc208'},
#  {'id': '229906736',
#   'verified': False,
#   'username': 'DirectorsTalk',
#   'name': 'DirectorsTalk'},
#  {'id': '4833242507',
#   'verified': False,
#   'username': 'runningprofits',
#   'location': 'United Kingdom',
#   'name': 'donncha @ runprofits.com'},
#  {'id': '1237055126281519104',
#   'verified': False,
#   'username': 'JRogers40817410',
#   'name': 'J Rogers'},
#  {'id': '1089867996158406656',
#   'verified': False,
#   'username': 'eumexmo99',
#   'location': 'Campinas, Brasil',
#   'name': 'minhapedraamestiça💎'},
#  {'id': '107367270',
#   'verified': False,
#   'username': 'RasheedMemon',
#   'location': 'Dubai, United Arab Emirates',
#   'name': '𝕽𝖆𝖘𝖍𝖊𝖊𝖉'},
#  {'id': '62481415',
#   'verified': False,
#   'username': 'gabormatesz',
#   'location': 'Miskolc, Hungary',
#   'name': '𝙶𝚊𝚋𝚘𝚛'},
#  {'id': '121370906',
#   'verified': False,
#   'username': 'ChartMill',
#   'location': 'Belgium',
#   'name': 'ChartMill'},
#  {'id': '20906444',
#   'verified': False,
#   'username': 'dannyrogers2001',
#   'location': 'London, England',
#   'name': 'Danny Rogers'},
#  {'id': '1372375318439288836',
#   'verified': False,
#   'username': 'itsmoizinho',
#   'location': 'Campina Grande, Brasil',
#   'name': 'Its Moizinho 🌻'},
#  {'id': '1495351200258084866',
#   'verified': False,
#   'username': 'stockosaur_com',
#   'name': 'stockosaur.com'},
#  {'id': '1522607300950863872',
#   'verified': False,
#   'username': 'bab_twins',
#   'name': 'Twins Bab'},
#  {'id': '1461613387',
#   'verified': False,
#   'username': 'PavolMacinga',
#   'location': 'Czech & Slovakia',
#   'name': 'Pavol Mačinga'},
#  {'id': '81170415',
#   'verified': False,
#   'username': 'effectbcw',
#   'location': 'Istanbul, Turkey',
#   'name': 'effect bcw'},
#  {'id': '49186493',
#   'verified': False,
#   'username': 'amandabrbz',
#   'location': 'Curitiba',
#   'name': 'Amanda'},
#  {'id': '50665199',
#   'verified': False,
#   'username': 'larigouveia',
#   'name': 'lari ruiva'},
#  {'id': '361829058',
#   'verified': False,
#   'username': 'SandyMidd',
#   'location': 'London, UK',
#   'name': 'Sandy'},
#  {'id': '1314739485930786818',
#   'verified': False,
#   'username': 'ElvitaNatassa',
#   'location': 'Bali, Indonesia',
#   'name': 'Brown Sugar Bali'},
#  {'id': '1559673867098095616',
#   'verified': False,
#   'username': 'RusticosBell',
#   'location': 'Moreno, Argentina',
#   'name': 'RústicosBell 🤯'}]

# %%
print(len(tweets_data))
print(len(tweets_users))
# Out:
# 52
# 32

# %%
# the different numbers let's us know some users did multiple tweets with #WPP
# transform to pandas dataframe
df_data = pd.json_normalize(tweets_data)
df_users = pd.json_normalize(tweets_users)

# %%
df_data
# Out:
#                      id                      source  \
# 0   1565738244372803585                    Tickeron
# 1   1565514952877686784             Twitter Web App
# 2   1565476711071973378          Twitter for iPhone
# 3   1565394482144587776                    Tickeron
# 4   1565331598324940802               Investor Feed
# 5   1565326212293091329              Hootsuite Inc.
# 6   1565311917236912130         Twitter for Android
# 7   1565291466947182598             Twitter Web App
# 8   1565283732222644224               Edgar Filings
# 9   1565281015643492352               Investor Feed
# 10  1565278011754221570             Twitter Web App
# 11  1565277293651677184         Proactive Investors
# 12  1565256760365125632            SwingTradeBot UK
# 13  1565250895146876928            Twitter for iPad
# 14  1565243385790619648                SilentTrades
# 15  1565229880807247872             Twitter Web App
# 16  1565228542174015489  DirectorsTalk Auto Posting
# 17  1565222526137126915             Twitter Web App
# 18  1565011514041724928          Twitter for iPhone
# 19  1565008272909897730          Twitter for iPhone
# 20  1564996152969289732        Twitterrific for iOS
# 21  1564995594342498305          Twitter for iPhone
# 22  1564988464403292162            SwingTradeBot UK
# 23  1564957689679159299           www.chartmill.com
# 24  1564851941976457217             Twitter Web App
# 25  1564792540645060611                    Tickeron
# 26  1564656560709992450          Twitter for iPhone
# 27  1564627325999800324            SwingTradeBot UK
# 28  1564608134399787012           www.chartmill.com
# 29  1564593281522143235             Twitter Web App
# 30  1564571615152717827         Twitter for Android
# 31  1564451608171352066           www.chartmill.com
# 32  1564443430289383424                     Twitter
# 33  1564362844107333635         Twitter for Android
# 34  1564302942793961472                    Tickeron
# 35  1564171443243556865             Twitter Web App
# 36  1564134267436912642         Twitter for Android
# 37  1564124074464395264            Twitter for iPad
# 38  1563955195440160768          Twitter for iPhone
# 39  1563925877049671686                    Tickeron
# 40  1563825477298622468           www.chartmill.com
# 41  1563594411480473600          Twitter for iPhone
# 42  1563503589678465025          Twitter for iPhone
# 43  1563496305296429057         Twitter for Android
# 44  1563452744375369729                     Twitter
# 45  1563449958568644608         Twitter for Android
# 46  1563449577591545857          Twitter for iPhone
# 47  1563424047077400584             Twitter Web App
# 48  1563376310831161344            SwingTradeBot UK
# 49  1563320903366504452           www.chartmill.com
# 50  1563269816362086402           www.chartmill.com
# 51  1563233368908906496         Twitter for Android
#
#                                                  text  \
# 0   $WPP enters a Downtrend as Momentum Indicator ...
# 1   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 2   @GiDavidswright Ay yo las amo, tengo botas y p...
# 3   $WPP's in Downtrend: Moving Average Convergenc...
# 4   $WPP  6-K  WPP   (1 Sep, 9:30am)\n\n📰 Total Vo...
# 5   @WPP Acquires Ecommerce Consultancy Newcraft h...
# 6              @JLD_200 #WPP\nhttps://t.co/cM0OVS2RtT
# 7   #WPP anuncia la adquisición de Newcraft\nhttps...
# 8   SEC Form 6-K  filed by  $WPP $WPPGF #WPP plc  ...
# 9   $WPP  6-K  WPP   (1 Sep, 6:08am)\n\n📰 Current ...
# 10  📣 We’re delighted to welcome Newcraft to the W...
# 11  $WPP WPP to buy European ecommerce consultancy...
# 12  New 52 Week Low today: #SBRY #RR #BDEV #TW #TP...
# 13  WPP snaps up Dutch ecommerce firm Newcraft ami...
# 14  #WPP acquires leading data-first European ecom...
# 15  Good Morning\n\nUK Newsflow:\n\n#BARC-sells AB...
# 16  '#WPP acquires leading data-first European eco...
# 17  238 #RNS in One\n\nTUs 39 incl #AEX #APH #CAM ...
# 18        @KatiePhang #WPP His new name is John Smith
# 19  #WPP pensando aqui se compro o iPhone 13PM sen...
# 20  We can supply high quality, strong &amp; tear ...
# 21  Agyam eldobom, a miskolci Freiben nem megy a k...
# 22  New 52 Week Low today: #ASTO #BLND #ABDN #WPP ...
# 23  $WPP.L has an average volume of 1535710. This ...
# 24  💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 25  $WPP's 10-day Moving Average crossed below its...
# 26                                    @B52Malmet #WPP
# 27  New 52 Week Low today: #PNN #HWDN #SN #HIK #WP...
# 28  $WPP.L has an average volume of 1518070. This ...
# 29  This anti- fossil fuel agency campaign is clea...
# 30  Gente, já aconteceu com vocês de as datas do w...
# 31  $WPP.L has an average volume of 1518070. This ...
# 32  #WPP the closest resistance level we identifie...
# 33                         @StockRocket1 #WPP \n$BOPO
# 34  $WPP's 10-day Moving Average broke below its 5...
# 35  💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 36            @JLD_200 #WPP \nhttps://t.co/cM0OVS2RtT
# 37  Spojenie #JanBinar &amp; #PetraPipkova tu uz b...
# 38  WPP Akademi podcast serisi Metaverse&amp;More ...
# 39  $WPP's 10-day Moving Average crossed below its...
# 40  $WPP.L has an average volume of 1518070. This ...
# 41  uma coisa que aprendi nesse tempo sem trabalho...
# 42  Não basta nao ter bolo de cenoura. Os caras nã...
# 43      @kucoincom #WPP $WPP\nhttps://t.co/cM0OVRLg5j
# 44  #WPP Regarding indicators, \nhttps://t.co/7aJo...
# 45  A sinking market; #DARK saved me recently, thi...
# 46               Woohoo! #WPP https://t.co/xU1bnlsvas
# 47  💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 48  #WPP technical alerts: New 52 Week Low and New...
# 49  $WPP.L has an average volume of 1518070. This ...
# 50  $WPP.L has an average volume of 1518070. This ...
# 51  Hola 👋👋 estamos #SORTEANDO un hermoso Mangrull...
#
#                   created_at lang            author_id      geo.place_id
# 0   2022-09-02T16:27:42.000Z   en            374729426               NaN
# 1   2022-09-02T01:40:25.000Z   en  1434909340205465605               NaN
# 2   2022-09-01T23:08:27.000Z   es  1260946502714904576               NaN
# 3   2022-09-01T17:41:42.000Z   en            374729426               NaN
# 4   2022-09-01T13:31:50.000Z   en  1171873456276889600               NaN
# 5   2022-09-01T13:10:26.000Z   en   799226790065508352               NaN
# 6   2022-09-01T12:13:37.000Z  qme  1340919529166221313               NaN
# 7   2022-09-01T10:52:22.000Z   es            114739070               NaN
# 8   2022-09-01T10:21:37.000Z   en  1068561714055012352               NaN
# 9   2022-09-01T10:10:50.000Z   en  1171873456276889600               NaN
# 10  2022-09-01T09:58:54.000Z   en             54319874               NaN
# 11  2022-09-01T09:56:02.000Z   en             22779605               NaN
# 12  2022-09-01T08:34:27.000Z   en   853342253804335107               NaN
# 13  2022-09-01T08:11:09.000Z   en            953592132               NaN
# 14  2022-09-01T07:41:18.000Z   en           4330144943               NaN
# 15  2022-09-01T06:47:38.000Z   en  1245383403454771201               NaN
# 16  2022-09-01T06:42:19.000Z   en            229906736               NaN
# 17  2022-09-01T06:18:25.000Z   en           4833242507               NaN
# 18  2022-08-31T16:19:56.000Z   en  1237055126281519104               NaN
# 19  2022-08-31T16:07:03.000Z   pt  1089867996158406656               NaN
# 20  2022-08-31T15:18:53.000Z   en            107367270               NaN
# 21  2022-08-31T15:16:40.000Z   hu             62481415  07d9f05b02881002
# 22  2022-08-31T14:48:20.000Z   en   853342253804335107               NaN
# 23  2022-08-31T12:46:03.000Z   en            121370906               NaN
# 24  2022-08-31T05:45:51.000Z   en  1434909340205465605               NaN
# 25  2022-08-31T01:49:48.000Z   en            374729426               NaN
# 26  2022-08-30T16:49:28.000Z  qme  1237055126281519104               NaN
# 27  2022-08-30T14:53:18.000Z   en   853342253804335107               NaN
# 28  2022-08-30T13:37:02.000Z   en            121370906               NaN
# 29  2022-08-30T12:38:01.000Z   en             20906444               NaN
# 30  2022-08-30T11:11:56.000Z   pt  1372375318439288836               NaN
# 31  2022-08-30T03:15:04.000Z   en            121370906               NaN
# 32  2022-08-30T02:42:34.000Z   en  1495351200258084866               NaN
# 33  2022-08-29T21:22:21.000Z   pt  1522607300950863872               NaN
# 34  2022-08-29T17:24:19.000Z   en            374729426               NaN
# 35  2022-08-29T08:41:47.000Z   en  1434909340205465605               NaN
# 36  2022-08-29T06:14:04.000Z  qme  1340919529166221313               NaN
# 37  2022-08-29T05:33:34.000Z  und           1461613387               NaN
# 38  2022-08-28T18:22:30.000Z   tr             81170415               NaN
# 39  2022-08-28T16:26:00.000Z   en            374729426               NaN
# 40  2022-08-28T09:47:02.000Z   en            121370906               NaN
# 41  2022-08-27T18:28:52.000Z   pt             49186493               NaN
# 42  2022-08-27T12:27:58.000Z   pt             50665199               NaN
# 43  2022-08-27T11:59:02.000Z  qme  1340919529166221313               NaN
# 44  2022-08-27T09:05:56.000Z   en  1495351200258084866               NaN
# 45  2022-08-27T08:54:52.000Z   en            361829058               NaN
# 46  2022-08-27T08:53:21.000Z   en  1314739485930786818               NaN
# 47  2022-08-27T07:11:54.000Z   en  1434909340205465605               NaN
# 48  2022-08-27T04:02:13.000Z   en   853342253804335107               NaN
# 49  2022-08-27T00:22:03.000Z   en            121370906               NaN
# 50  2022-08-26T20:59:03.000Z   en            121370906               NaN
# 51  2022-08-26T18:34:13.000Z   es  1559673867098095616               NaN

# %%
df_users
# Out:
#                      id  verified         username  \
# 0             374729426     False         Tickeron
# 1   1434909340205465605     False   SuccessAfter25
# 2   1260946502714904576     False       lahannadom
# 3   1171873456276889600     False    investor_feed
# 4    799226790065508352     False    MarTechSeries
# 5   1340919529166221313     False          TZokani
# 6             114739070     False  PdelaPublicidad
# 7   1068561714055012352     False     EdgarInsider
# 8              54319874      True      WunThompson
# 9              22779605     False     proactive_UK
# 10   853342253804335107     False  SwingTradeBotUK
# 11            953592132     False   andrewsduncan1
# 12           4330144943     False    silent_trades
# 13  1245383403454771201     False      andrewdc208
# 14            229906736     False    DirectorsTalk
# 15           4833242507     False   runningprofits
# 16  1237055126281519104     False  JRogers40817410
# 17  1089867996158406656     False        eumexmo99
# 18            107367270     False     RasheedMemon
# 19             62481415     False      gabormatesz
# 20            121370906     False        ChartMill
# 21             20906444     False  dannyrogers2001
# 22  1372375318439288836     False      itsmoizinho
# 23  1495351200258084866     False   stockosaur_com
# 24  1522607300950863872     False        bab_twins
# 25           1461613387     False     PavolMacinga
# 26             81170415     False        effectbcw
# 27             49186493     False       amandabrbz
# 28             50665199     False      larigouveia
# 29            361829058     False        SandyMidd
# 30  1314739485930786818     False    ElvitaNatassa
# 31  1559673867098095616     False     RusticosBell
#
#                        location                      name
# 0                 Sunnyvale, CA                  Tickeron
# 1                           NaN               Trader PLUS
# 2       Buenos Aires, Argentina                      Anto
# 3               Toronto, Canada                Docoh Feed
# 4                 Hawthorne, CA            MarTech Series
# 5                           NaN              Tarek Zokani
# 6                 Madrid, Spain      Periódico PublicidAD
# 7                           NaN                SEC.report
# 8                        Global        Wunderman Thompson
# 9               London, England                 Proactive
# 10              London, England          SwingTradeBot UK
# 11       London. United Kingdom             Andrew Duncan
# 12                          NaN         Francis Alexander
# 13              London, England               Andrewdc208
# 14                          NaN             DirectorsTalk
# 15               United Kingdom  donncha @ runprofits.com
# 16                          NaN                  J Rogers
# 17             Campinas, Brasil       minhapedraamestiça💎
# 18  Dubai, United Arab Emirates                   𝕽𝖆𝖘𝖍𝖊𝖊𝖉
# 19             Miskolc, Hungary                     𝙶𝚊𝚋𝚘𝚛
# 20                      Belgium                 ChartMill
# 21              London, England              Danny Rogers
# 22       Campina Grande, Brasil            Its Moizinho 🌻
# 23                          NaN            stockosaur.com
# 24                          NaN                 Twins Bab
# 25             Czech & Slovakia             Pavol Mačinga
# 26             Istanbul, Turkey                effect bcw
# 27                     Curitiba                    Amanda
# 28                          NaN                lari ruiva
# 29                   London, UK                     Sandy
# 30              Bali, Indonesia          Brown Sugar Bali
# 31            Moreno, Argentina            RústicosBell 🤯

# %%
# I want to merge these two data frames together. 
# I can see author_id in my data dataframe, and id in my users dataframe is what connect the two
# let's make sure both columns use 'author_id' so pandas can merge the two
df_users.rename(columns={'id': 'author_id'}, inplace=True)
df_users
# Out:
#               author_id  verified         username  \
# 0             374729426     False         Tickeron
# 1   1434909340205465605     False   SuccessAfter25
# 2   1260946502714904576     False       lahannadom
# 3   1171873456276889600     False    investor_feed
# 4    799226790065508352     False    MarTechSeries
# 5   1340919529166221313     False          TZokani
# 6             114739070     False  PdelaPublicidad
# 7   1068561714055012352     False     EdgarInsider
# 8              54319874      True      WunThompson
# 9              22779605     False     proactive_UK
# 10   853342253804335107     False  SwingTradeBotUK
# 11            953592132     False   andrewsduncan1
# 12           4330144943     False    silent_trades
# 13  1245383403454771201     False      andrewdc208
# 14            229906736     False    DirectorsTalk
# 15           4833242507     False   runningprofits
# 16  1237055126281519104     False  JRogers40817410
# 17  1089867996158406656     False        eumexmo99
# 18            107367270     False     RasheedMemon
# 19             62481415     False      gabormatesz
# 20            121370906     False        ChartMill
# 21             20906444     False  dannyrogers2001
# 22  1372375318439288836     False      itsmoizinho
# 23  1495351200258084866     False   stockosaur_com
# 24  1522607300950863872     False        bab_twins
# 25           1461613387     False     PavolMacinga
# 26             81170415     False        effectbcw
# 27             49186493     False       amandabrbz
# 28             50665199     False      larigouveia
# 29            361829058     False        SandyMidd
# 30  1314739485930786818     False    ElvitaNatassa
# 31  1559673867098095616     False     RusticosBell
#
#                        location                      name
# 0                 Sunnyvale, CA                  Tickeron
# 1                           NaN               Trader PLUS
# 2       Buenos Aires, Argentina                      Anto
# 3               Toronto, Canada                Docoh Feed
# 4                 Hawthorne, CA            MarTech Series
# 5                           NaN              Tarek Zokani
# 6                 Madrid, Spain      Periódico PublicidAD
# 7                           NaN                SEC.report
# 8                        Global        Wunderman Thompson
# 9               London, England                 Proactive
# 10              London, England          SwingTradeBot UK
# 11       London. United Kingdom             Andrew Duncan
# 12                          NaN         Francis Alexander
# 13              London, England               Andrewdc208
# 14                          NaN             DirectorsTalk
# 15               United Kingdom  donncha @ runprofits.com
# 16                          NaN                  J Rogers
# 17             Campinas, Brasil       minhapedraamestiça💎
# 18  Dubai, United Arab Emirates                   𝕽𝖆𝖘𝖍𝖊𝖊𝖉
# 19             Miskolc, Hungary                     𝙶𝚊𝚋𝚘𝚛
# 20                      Belgium                 ChartMill
# 21              London, England              Danny Rogers
# 22       Campina Grande, Brasil            Its Moizinho 🌻
# 23                          NaN            stockosaur.com
# 24                          NaN                 Twins Bab
# 25             Czech & Slovakia             Pavol Mačinga
# 26             Istanbul, Turkey                effect bcw
# 27                     Curitiba                    Amanda
# 28                          NaN                lari ruiva
# 29                   London, UK                     Sandy
# 30              Bali, Indonesia          Brown Sugar Bali
# 31            Moreno, Argentina            RústicosBell 🤯

# %%
# Now I can merge our two DataFrames
df_merged = df_data.merge(df_users, on='author_id')
df_merged
# Out:
#                      id                      source  \
# 0   1565738244372803585                    Tickeron
# 1   1565394482144587776                    Tickeron
# 2   1564792540645060611                    Tickeron
# 3   1564302942793961472                    Tickeron
# 4   1563925877049671686                    Tickeron
# 5   1565514952877686784             Twitter Web App
# 6   1564851941976457217             Twitter Web App
# 7   1564171443243556865             Twitter Web App
# 8   1563424047077400584             Twitter Web App
# 9   1565476711071973378          Twitter for iPhone
# 10  1565331598324940802               Investor Feed
# 11  1565281015643492352               Investor Feed
# 12  1565326212293091329              Hootsuite Inc.
# 13  1565311917236912130         Twitter for Android
# 14  1564134267436912642         Twitter for Android
# 15  1563496305296429057         Twitter for Android
# 16  1565291466947182598             Twitter Web App
# 17  1565283732222644224               Edgar Filings
# 18  1565278011754221570             Twitter Web App
# 19  1565277293651677184         Proactive Investors
# 20  1565256760365125632            SwingTradeBot UK
# 21  1564988464403292162            SwingTradeBot UK
# 22  1564627325999800324            SwingTradeBot UK
# 23  1563376310831161344            SwingTradeBot UK
# 24  1565250895146876928            Twitter for iPad
# 25  1565243385790619648                SilentTrades
# 26  1565229880807247872             Twitter Web App
# 27  1565228542174015489  DirectorsTalk Auto Posting
# 28  1565222526137126915             Twitter Web App
# 29  1565011514041724928          Twitter for iPhone
# 30  1564656560709992450          Twitter for iPhone
# 31  1565008272909897730          Twitter for iPhone
# 32  1564996152969289732        Twitterrific for iOS
# 33  1564995594342498305          Twitter for iPhone
# 34  1564957689679159299           www.chartmill.com
# 35  1564608134399787012           www.chartmill.com
# 36  1564451608171352066           www.chartmill.com
# 37  1563825477298622468           www.chartmill.com
# 38  1563320903366504452           www.chartmill.com
# 39  1563269816362086402           www.chartmill.com
# 40  1564593281522143235             Twitter Web App
# 41  1564571615152717827         Twitter for Android
# 42  1564443430289383424                     Twitter
# 43  1563452744375369729                     Twitter
# 44  1564362844107333635         Twitter for Android
# 45  1564124074464395264            Twitter for iPad
# 46  1563955195440160768          Twitter for iPhone
# 47  1563594411480473600          Twitter for iPhone
# 48  1563503589678465025          Twitter for iPhone
# 49  1563449958568644608         Twitter for Android
# 50  1563449577591545857          Twitter for iPhone
# 51  1563233368908906496         Twitter for Android
#
#                                                  text  \
# 0   $WPP enters a Downtrend as Momentum Indicator ...
# 1   $WPP's in Downtrend: Moving Average Convergenc...
# 2   $WPP's 10-day Moving Average crossed below its...
# 3   $WPP's 10-day Moving Average broke below its 5...
# 4   $WPP's 10-day Moving Average crossed below its...
# 5   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 6   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 7   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 8   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...
# 9   @GiDavidswright Ay yo las amo, tengo botas y p...
# 10  $WPP  6-K  WPP   (1 Sep, 9:30am)\n\n📰 Total Vo...
# 11  $WPP  6-K  WPP   (1 Sep, 6:08am)\n\n📰 Current ...
# 12  @WPP Acquires Ecommerce Consultancy Newcraft h...
# 13             @JLD_200 #WPP\nhttps://t.co/cM0OVS2RtT
# 14            @JLD_200 #WPP \nhttps://t.co/cM0OVS2RtT
# 15      @kucoincom #WPP $WPP\nhttps://t.co/cM0OVRLg5j
# 16  #WPP anuncia la adquisición de Newcraft\nhttps...
# 17  SEC Form 6-K  filed by  $WPP $WPPGF #WPP plc  ...
# 18  📣 We’re delighted to welcome Newcraft to the W...
# 19  $WPP WPP to buy European ecommerce consultancy...
# 20  New 52 Week Low today: #SBRY #RR #BDEV #TW #TP...
# 21  New 52 Week Low today: #ASTO #BLND #ABDN #WPP ...
# 22  New 52 Week Low today: #PNN #HWDN #SN #HIK #WP...
# 23  #WPP technical alerts: New 52 Week Low and New...
# 24  WPP snaps up Dutch ecommerce firm Newcraft ami...
# 25  #WPP acquires leading data-first European ecom...
# 26  Good Morning\n\nUK Newsflow:\n\n#BARC-sells AB...
# 27  '#WPP acquires leading data-first European eco...
# 28  238 #RNS in One\n\nTUs 39 incl #AEX #APH #CAM ...
# 29        @KatiePhang #WPP His new name is John Smith
# 30                                    @B52Malmet #WPP
# 31  #WPP pensando aqui se compro o iPhone 13PM sen...
# 32  We can supply high quality, strong &amp; tear ...
# 33  Agyam eldobom, a miskolci Freiben nem megy a k...
# 34  $WPP.L has an average volume of 1535710. This ...
# 35  $WPP.L has an average volume of 1518070. This ...
# 36  $WPP.L has an average volume of 1518070. This ...
# 37  $WPP.L has an average volume of 1518070. This ...
# 38  $WPP.L has an average volume of 1518070. This ...
# 39  $WPP.L has an average volume of 1518070. This ...
# 40  This anti- fossil fuel agency campaign is clea...
# 41  Gente, já aconteceu com vocês de as datas do w...
# 42  #WPP the closest resistance level we identifie...
# 43  #WPP Regarding indicators, \nhttps://t.co/7aJo...
# 44                         @StockRocket1 #WPP \n$BOPO
# 45  Spojenie #JanBinar &amp; #PetraPipkova tu uz b...
# 46  WPP Akademi podcast serisi Metaverse&amp;More ...
# 47  uma coisa que aprendi nesse tempo sem trabalho...
# 48  Não basta nao ter bolo de cenoura. Os caras nã...
# 49  A sinking market; #DARK saved me recently, thi...
# 50               Woohoo! #WPP https://t.co/xU1bnlsvas
# 51  Hola 👋👋 estamos #SORTEANDO un hermoso Mangrull...
#
#                   created_at lang            author_id      geo.place_id  \
# 0   2022-09-02T16:27:42.000Z   en            374729426               NaN
# 1   2022-09-01T17:41:42.000Z   en            374729426               NaN
# 2   2022-08-31T01:49:48.000Z   en            374729426               NaN
# 3   2022-08-29T17:24:19.000Z   en            374729426               NaN
# 4   2022-08-28T16:26:00.000Z   en            374729426               NaN
# 5   2022-09-02T01:40:25.000Z   en  1434909340205465605               NaN
# 6   2022-08-31T05:45:51.000Z   en  1434909340205465605               NaN
# 7   2022-08-29T08:41:47.000Z   en  1434909340205465605               NaN
# 8   2022-08-27T07:11:54.000Z   en  1434909340205465605               NaN
# 9   2022-09-01T23:08:27.000Z   es  1260946502714904576               NaN
# 10  2022-09-01T13:31:50.000Z   en  1171873456276889600               NaN
# 11  2022-09-01T10:10:50.000Z   en  1171873456276889600               NaN
# 12  2022-09-01T13:10:26.000Z   en   799226790065508352               NaN
# 13  2022-09-01T12:13:37.000Z  qme  1340919529166221313               NaN
# 14  2022-08-29T06:14:04.000Z  qme  1340919529166221313               NaN
# 15  2022-08-27T11:59:02.000Z  qme  1340919529166221313               NaN
# 16  2022-09-01T10:52:22.000Z   es            114739070               NaN
# 17  2022-09-01T10:21:37.000Z   en  1068561714055012352               NaN
# 18  2022-09-01T09:58:54.000Z   en             54319874               NaN
# 19  2022-09-01T09:56:02.000Z   en             22779605               NaN
# 20  2022-09-01T08:34:27.000Z   en   853342253804335107               NaN
# 21  2022-08-31T14:48:20.000Z   en   853342253804335107               NaN
# 22  2022-08-30T14:53:18.000Z   en   853342253804335107               NaN
# 23  2022-08-27T04:02:13.000Z   en   853342253804335107               NaN
# 24  2022-09-01T08:11:09.000Z   en            953592132               NaN
# 25  2022-09-01T07:41:18.000Z   en           4330144943               NaN
# 26  2022-09-01T06:47:38.000Z   en  1245383403454771201               NaN
# 27  2022-09-01T06:42:19.000Z   en            229906736               NaN
# 28  2022-09-01T06:18:25.000Z   en           4833242507               NaN
# 29  2022-08-31T16:19:56.000Z   en  1237055126281519104               NaN
# 30  2022-08-30T16:49:28.000Z  qme  1237055126281519104               NaN
# 31  2022-08-31T16:07:03.000Z   pt  1089867996158406656               NaN
# 32  2022-08-31T15:18:53.000Z   en            107367270               NaN
# 33  2022-08-31T15:16:40.000Z   hu             62481415  07d9f05b02881002
# 34  2022-08-31T12:46:03.000Z   en            121370906               NaN
# 35  2022-08-30T13:37:02.000Z   en            121370906               NaN
# 36  2022-08-30T03:15:04.000Z   en            121370906               NaN
# 37  2022-08-28T09:47:02.000Z   en            121370906               NaN
# 38  2022-08-27T00:22:03.000Z   en            121370906               NaN
# 39  2022-08-26T20:59:03.000Z   en            121370906               NaN
# 40  2022-08-30T12:38:01.000Z   en             20906444               NaN
# 41  2022-08-30T11:11:56.000Z   pt  1372375318439288836               NaN
# 42  2022-08-30T02:42:34.000Z   en  1495351200258084866               NaN
# 43  2022-08-27T09:05:56.000Z   en  1495351200258084866               NaN
# 44  2022-08-29T21:22:21.000Z   pt  1522607300950863872               NaN
# 45  2022-08-29T05:33:34.000Z  und           1461613387               NaN
# 46  2022-08-28T18:22:30.000Z   tr             81170415               NaN
# 47  2022-08-27T18:28:52.000Z   pt             49186493               NaN
# 48  2022-08-27T12:27:58.000Z   pt             50665199               NaN
# 49  2022-08-27T08:54:52.000Z   en            361829058               NaN
# 50  2022-08-27T08:53:21.000Z   en  1314739485930786818               NaN
# 51  2022-08-26T18:34:13.000Z   es  1559673867098095616               NaN
#
#     verified         username                     location  \
# 0      False         Tickeron                Sunnyvale, CA
# 1      False         Tickeron                Sunnyvale, CA
# 2      False         Tickeron                Sunnyvale, CA
# 3      False         Tickeron                Sunnyvale, CA
# 4      False         Tickeron                Sunnyvale, CA
# 5      False   SuccessAfter25                          NaN
# 6      False   SuccessAfter25                          NaN
# 7      False   SuccessAfter25                          NaN
# 8      False   SuccessAfter25                          NaN
# 9      False       lahannadom      Buenos Aires, Argentina
# 10     False    investor_feed              Toronto, Canada
# 11     False    investor_feed              Toronto, Canada
# 12     False    MarTechSeries                Hawthorne, CA
# 13     False          TZokani                          NaN
# 14     False          TZokani                          NaN
# 15     False          TZokani                          NaN
# 16     False  PdelaPublicidad                Madrid, Spain
# 17     False     EdgarInsider                          NaN
# 18      True      WunThompson                       Global
# 19     False     proactive_UK              London, England
# 20     False  SwingTradeBotUK              London, England
# 21     False  SwingTradeBotUK              London, England
# 22     False  SwingTradeBotUK              London, England
# 23     False  SwingTradeBotUK              London, England
# 24     False   andrewsduncan1       London. United Kingdom
# 25     False    silent_trades                          NaN
# 26     False      andrewdc208              London, England
# 27     False    DirectorsTalk                          NaN
# 28     False   runningprofits               United Kingdom
# 29     False  JRogers40817410                          NaN
# 30     False  JRogers40817410                          NaN
# 31     False        eumexmo99             Campinas, Brasil
# 32     False     RasheedMemon  Dubai, United Arab Emirates
# 33     False      gabormatesz             Miskolc, Hungary
# 34     False        ChartMill                      Belgium
# 35     False        ChartMill                      Belgium
# 36     False        ChartMill                      Belgium
# 37     False        ChartMill                      Belgium
# 38     False        ChartMill                      Belgium
# 39     False        ChartMill                      Belgium
# 40     False  dannyrogers2001              London, England
# 41     False      itsmoizinho       Campina Grande, Brasil
# 42     False   stockosaur_com                          NaN
# 43     False   stockosaur_com                          NaN
# 44     False        bab_twins                          NaN
# 45     False     PavolMacinga             Czech & Slovakia
# 46     False        effectbcw             Istanbul, Turkey
# 47     False       amandabrbz                     Curitiba
# 48     False      larigouveia                          NaN
# 49     False        SandyMidd                   London, UK
# 50     False    ElvitaNatassa              Bali, Indonesia
# 51     False     RusticosBell            Moreno, Argentina
#
#                         name
# 0                   Tickeron
# 1                   Tickeron
# 2                   Tickeron
# 3                   Tickeron
# 4                   Tickeron
# 5                Trader PLUS
# 6                Trader PLUS
# 7                Trader PLUS
# 8                Trader PLUS
# 9                       Anto
# 10                Docoh Feed
# 11                Docoh Feed
# 12            MarTech Series
# 13              Tarek Zokani
# 14              Tarek Zokani
# 15              Tarek Zokani
# 16      Periódico PublicidAD
# 17                SEC.report
# 18        Wunderman Thompson
# 19                 Proactive
# 20          SwingTradeBot UK
# 21          SwingTradeBot UK
# 22          SwingTradeBot UK
# 23          SwingTradeBot UK
# 24             Andrew Duncan
# 25         Francis Alexander
# 26               Andrewdc208
# 27             DirectorsTalk
# 28  donncha @ runprofits.com
# 29                  J Rogers
# 30                  J Rogers
# 31       minhapedraamestiça💎
# 32                   𝕽𝖆𝖘𝖍𝖊𝖊𝖉
# 33                     𝙶𝚊𝚋𝚘𝚛
# 34                 ChartMill
# 35                 ChartMill
# 36                 ChartMill
# 37                 ChartMill
# 38                 ChartMill
# 39                 ChartMill
# 40              Danny Rogers
# 41            Its Moizinho 🌻
# 42            stockosaur.com
# 43            stockosaur.com
# 44                 Twins Bab
# 45             Pavol Mačinga
# 46                effect bcw
# 47                    Amanda
# 48                lari ruiva
# 49                     Sandy
# 50          Brown Sugar Bali
# 51            RústicosBell 🤯

# %%
# the created_at time is a little difficult to read so let's fix that
df_merged["created_at"] = df_merged["created_at"].dt.strftime('%d-%m-%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19496\316562082.py in <module>
#       1 # the created_at time is a little difficult to read so let's fix that
# ----> 2 df_merged["created_at"] = df_merged["created_at"].dt.strftime('%d-%m-%Y')
#
# ~\School\Classes\wpp-python-intro\Class06-BotsPart1\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\School\Classes\wpp-python-intro\Class06-BotsPart1\venv\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~\School\Classes\wpp-python-intro\Class06-BotsPart1\venv\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     504             return PeriodProperties(data, orig)
#     505
# --> 506         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
# this didn't work!
# let's just the type value of "created_at"
print(type(df_merged.iloc[0].created_at))
# Out:
# <class 'str'>

# %%
# it's a string, so we need to convert to this a DateTime object first
df_merged['created_at'] = pd.to_datetime(df_merged['created_at'])
df_merged["created_at"] = df_merged["created_at"].dt.strftime('%d-%m-%Y %H:%M')
df_merged
# Out:
#                      id                      source  \
# 0   1565738244372803585                    Tickeron
# 1   1565394482144587776                    Tickeron
# 2   1564792540645060611                    Tickeron
# 3   1564302942793961472                    Tickeron
# 4   1563925877049671686                    Tickeron
# 5   1565514952877686784             Twitter Web App
# 6   1564851941976457217             Twitter Web App
# 7   1564171443243556865             Twitter Web App
# 8   1563424047077400584             Twitter Web App
# 9   1565476711071973378          Twitter for iPhone
# 10  1565331598324940802               Investor Feed
# 11  1565281015643492352               Investor Feed
# 12  1565326212293091329              Hootsuite Inc.
# 13  1565311917236912130         Twitter for Android
# 14  1564134267436912642         Twitter for Android
# 15  1563496305296429057         Twitter for Android
# 16  1565291466947182598             Twitter Web App
# 17  1565283732222644224               Edgar Filings
# 18  1565278011754221570             Twitter Web App
# 19  1565277293651677184         Proactive Investors
# 20  1565256760365125632            SwingTradeBot UK
# 21  1564988464403292162            SwingTradeBot UK
# 22  1564627325999800324            SwingTradeBot UK
# 23  1563376310831161344            SwingTradeBot UK
# 24  1565250895146876928            Twitter for iPad
# 25  1565243385790619648                SilentTrades
# 26  1565229880807247872             Twitter Web App
# 27  1565228542174015489  DirectorsTalk Auto Posting
# 28  1565222526137126915             Twitter Web App
# 29  1565011514041724928          Twitter for iPhone
# 30  1564656560709992450          Twitter for iPhone
# 31  1565008272909897730          Twitter for iPhone
# 32  1564996152969289732        Twitterrific for iOS
# 33  1564995594342498305          Twitter for iPhone
# 34  1564957689679159299           www.chartmill.com
# 35  1564608134399787012           www.chartmill.com
# 36  1564451608171352066           www.chartmill.com
# 37  1563825477298622468           www.chartmill.com
# 38  1563320903366504452           www.chartmill.com
# 39  1563269816362086402           www.chartmill.com
# 40  1564593281522143235             Twitter Web App
# 41  1564571615152717827         Twitter for Android
# 42  1564443430289383424                     Twitter
# 43  1563452744375369729                     Twitter
# 44  1564362844107333635         Twitter for Android
# 45  1564124074464395264            Twitter for iPad
# 46  1563955195440160768          Twitter for iPhone
# 47  1563594411480473600          Twitter for iPhone
# 48  1563503589678465025          Twitter for iPhone
# 49  1563449958568644608         Twitter for Android
# 50  1563449577591545857          Twitter for iPhone
# 51  1563233368908906496         Twitter for Android
#
#                                                  text        created_at lang  \
# 0   $WPP enters a Downtrend as Momentum Indicator ...  02-09-2022 16:27   en
# 1   $WPP's in Downtrend: Moving Average Convergenc...  01-09-2022 17:41   en
# 2   $WPP's 10-day Moving Average crossed below its...  31-08-2022 01:49   en
# 3   $WPP's 10-day Moving Average broke below its 5...  29-08-2022 17:24   en
# 4   $WPP's 10-day Moving Average crossed below its...  28-08-2022 16:26   en
# 5   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  02-09-2022 01:40   en
# 6   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  31-08-2022 05:45   en
# 7   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  29-08-2022 08:41   en
# 8   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  27-08-2022 07:11   en
# 9   @GiDavidswright Ay yo las amo, tengo botas y p...  01-09-2022 23:08   es
# 10  $WPP  6-K  WPP   (1 Sep, 9:30am)\n\n📰 Total Vo...  01-09-2022 13:31   en
# 11  $WPP  6-K  WPP   (1 Sep, 6:08am)\n\n📰 Current ...  01-09-2022 10:10   en
# 12  @WPP Acquires Ecommerce Consultancy Newcraft h...  01-09-2022 13:10   en
# 13             @JLD_200 #WPP\nhttps://t.co/cM0OVS2RtT  01-09-2022 12:13  qme
# 14            @JLD_200 #WPP \nhttps://t.co/cM0OVS2RtT  29-08-2022 06:14  qme
# 15      @kucoincom #WPP $WPP\nhttps://t.co/cM0OVRLg5j  27-08-2022 11:59  qme
# 16  #WPP anuncia la adquisición de Newcraft\nhttps...  01-09-2022 10:52   es
# 17  SEC Form 6-K  filed by  $WPP $WPPGF #WPP plc  ...  01-09-2022 10:21   en
# 18  📣 We’re delighted to welcome Newcraft to the W...  01-09-2022 09:58   en
# 19  $WPP WPP to buy European ecommerce consultancy...  01-09-2022 09:56   en
# 20  New 52 Week Low today: #SBRY #RR #BDEV #TW #TP...  01-09-2022 08:34   en
# 21  New 52 Week Low today: #ASTO #BLND #ABDN #WPP ...  31-08-2022 14:48   en
# 22  New 52 Week Low today: #PNN #HWDN #SN #HIK #WP...  30-08-2022 14:53   en
# 23  #WPP technical alerts: New 52 Week Low and New...  27-08-2022 04:02   en
# 24  WPP snaps up Dutch ecommerce firm Newcraft ami...  01-09-2022 08:11   en
# 25  #WPP acquires leading data-first European ecom...  01-09-2022 07:41   en
# 26  Good Morning\n\nUK Newsflow:\n\n#BARC-sells AB...  01-09-2022 06:47   en
# 27  '#WPP acquires leading data-first European eco...  01-09-2022 06:42   en
# 28  238 #RNS in One\n\nTUs 39 incl #AEX #APH #CAM ...  01-09-2022 06:18   en
# 29        @KatiePhang #WPP His new name is John Smith  31-08-2022 16:19   en
# 30                                    @B52Malmet #WPP  30-08-2022 16:49  qme
# 31  #WPP pensando aqui se compro o iPhone 13PM sen...  31-08-2022 16:07   pt
# 32  We can supply high quality, strong &amp; tear ...  31-08-2022 15:18   en
# 33  Agyam eldobom, a miskolci Freiben nem megy a k...  31-08-2022 15:16   hu
# 34  $WPP.L has an average volume of 1535710. This ...  31-08-2022 12:46   en
# 35  $WPP.L has an average volume of 1518070. This ...  30-08-2022 13:37   en
# 36  $WPP.L has an average volume of 1518070. This ...  30-08-2022 03:15   en
# 37  $WPP.L has an average volume of 1518070. This ...  28-08-2022 09:47   en
# 38  $WPP.L has an average volume of 1518070. This ...  27-08-2022 00:22   en
# 39  $WPP.L has an average volume of 1518070. This ...  26-08-2022 20:59   en
# 40  This anti- fossil fuel agency campaign is clea...  30-08-2022 12:38   en
# 41  Gente, já aconteceu com vocês de as datas do w...  30-08-2022 11:11   pt
# 42  #WPP the closest resistance level we identifie...  30-08-2022 02:42   en
# 43  #WPP Regarding indicators, \nhttps://t.co/7aJo...  27-08-2022 09:05   en
# 44                         @StockRocket1 #WPP \n$BOPO  29-08-2022 21:22   pt
# 45  Spojenie #JanBinar &amp; #PetraPipkova tu uz b...  29-08-2022 05:33  und
# 46  WPP Akademi podcast serisi Metaverse&amp;More ...  28-08-2022 18:22   tr
# 47  uma coisa que aprendi nesse tempo sem trabalho...  27-08-2022 18:28   pt
# 48  Não basta nao ter bolo de cenoura. Os caras nã...  27-08-2022 12:27   pt
# 49  A sinking market; #DARK saved me recently, thi...  27-08-2022 08:54   en
# 50               Woohoo! #WPP https://t.co/xU1bnlsvas  27-08-2022 08:53   en
# 51  Hola 👋👋 estamos #SORTEANDO un hermoso Mangrull...  26-08-2022 18:34   es
#
#               author_id      geo.place_id  verified         username  \
# 0             374729426               NaN     False         Tickeron
# 1             374729426               NaN     False         Tickeron
# 2             374729426               NaN     False         Tickeron
# 3             374729426               NaN     False         Tickeron
# 4             374729426               NaN     False         Tickeron
# 5   1434909340205465605               NaN     False   SuccessAfter25
# 6   1434909340205465605               NaN     False   SuccessAfter25
# 7   1434909340205465605               NaN     False   SuccessAfter25
# 8   1434909340205465605               NaN     False   SuccessAfter25
# 9   1260946502714904576               NaN     False       lahannadom
# 10  1171873456276889600               NaN     False    investor_feed
# 11  1171873456276889600               NaN     False    investor_feed
# 12   799226790065508352               NaN     False    MarTechSeries
# 13  1340919529166221313               NaN     False          TZokani
# 14  1340919529166221313               NaN     False          TZokani
# 15  1340919529166221313               NaN     False          TZokani
# 16            114739070               NaN     False  PdelaPublicidad
# 17  1068561714055012352               NaN     False     EdgarInsider
# 18             54319874               NaN      True      WunThompson
# 19             22779605               NaN     False     proactive_UK
# 20   853342253804335107               NaN     False  SwingTradeBotUK
# 21   853342253804335107               NaN     False  SwingTradeBotUK
# 22   853342253804335107               NaN     False  SwingTradeBotUK
# 23   853342253804335107               NaN     False  SwingTradeBotUK
# 24            953592132               NaN     False   andrewsduncan1
# 25           4330144943               NaN     False    silent_trades
# 26  1245383403454771201               NaN     False      andrewdc208
# 27            229906736               NaN     False    DirectorsTalk
# 28           4833242507               NaN     False   runningprofits
# 29  1237055126281519104               NaN     False  JRogers40817410
# 30  1237055126281519104               NaN     False  JRogers40817410
# 31  1089867996158406656               NaN     False        eumexmo99
# 32            107367270               NaN     False     RasheedMemon
# 33             62481415  07d9f05b02881002     False      gabormatesz
# 34            121370906               NaN     False        ChartMill
# 35            121370906               NaN     False        ChartMill
# 36            121370906               NaN     False        ChartMill
# 37            121370906               NaN     False        ChartMill
# 38            121370906               NaN     False        ChartMill
# 39            121370906               NaN     False        ChartMill
# 40             20906444               NaN     False  dannyrogers2001
# 41  1372375318439288836               NaN     False      itsmoizinho
# 42  1495351200258084866               NaN     False   stockosaur_com
# 43  1495351200258084866               NaN     False   stockosaur_com
# 44  1522607300950863872               NaN     False        bab_twins
# 45           1461613387               NaN     False     PavolMacinga
# 46             81170415               NaN     False        effectbcw
# 47             49186493               NaN     False       amandabrbz
# 48             50665199               NaN     False      larigouveia
# 49            361829058               NaN     False        SandyMidd
# 50  1314739485930786818               NaN     False    ElvitaNatassa
# 51  1559673867098095616               NaN     False     RusticosBell
#
#                        location                      name
# 0                 Sunnyvale, CA                  Tickeron
# 1                 Sunnyvale, CA                  Tickeron
# 2                 Sunnyvale, CA                  Tickeron
# 3                 Sunnyvale, CA                  Tickeron
# 4                 Sunnyvale, CA                  Tickeron
# 5                           NaN               Trader PLUS
# 6                           NaN               Trader PLUS
# 7                           NaN               Trader PLUS
# 8                           NaN               Trader PLUS
# 9       Buenos Aires, Argentina                      Anto
# 10              Toronto, Canada                Docoh Feed
# 11              Toronto, Canada                Docoh Feed
# 12                Hawthorne, CA            MarTech Series
# 13                          NaN              Tarek Zokani
# 14                          NaN              Tarek Zokani
# 15                          NaN              Tarek Zokani
# 16                Madrid, Spain      Periódico PublicidAD
# 17                          NaN                SEC.report
# 18                       Global        Wunderman Thompson
# 19              London, England                 Proactive
# 20              London, England          SwingTradeBot UK
# 21              London, England          SwingTradeBot UK
# 22              London, England          SwingTradeBot UK
# 23              London, England          SwingTradeBot UK
# 24       London. United Kingdom             Andrew Duncan
# 25                          NaN         Francis Alexander
# 26              London, England               Andrewdc208
# 27                          NaN             DirectorsTalk
# 28               United Kingdom  donncha @ runprofits.com
# 29                          NaN                  J Rogers
# 30                          NaN                  J Rogers
# 31             Campinas, Brasil       minhapedraamestiça💎
# 32  Dubai, United Arab Emirates                   𝕽𝖆𝖘𝖍𝖊𝖊𝖉
# 33             Miskolc, Hungary                     𝙶𝚊𝚋𝚘𝚛
# 34                      Belgium                 ChartMill
# 35                      Belgium                 ChartMill
# 36                      Belgium                 ChartMill
# 37                      Belgium                 ChartMill
# 38                      Belgium                 ChartMill
# 39                      Belgium                 ChartMill
# 40              London, England              Danny Rogers
# 41       Campina Grande, Brasil            Its Moizinho 🌻
# 42                          NaN            stockosaur.com
# 43                          NaN            stockosaur.com
# 44                          NaN                 Twins Bab
# 45             Czech & Slovakia             Pavol Mačinga
# 46             Istanbul, Turkey                effect bcw
# 47                     Curitiba                    Amanda
# 48                          NaN                lari ruiva
# 49                   London, UK                     Sandy
# 50              Bali, Indonesia          Brown Sugar Bali
# 51            Moreno, Argentina            RústicosBell 🤯

# %%
# better!
# I also don't care about the ids anymore, so let's get rid of those
# 1 is the axis number (0 for rows and 1 for columns.)
df_merged.drop(['author_id','id'], axis=1)
# Out:
#                         source  \
# 0                     Tickeron
# 1                     Tickeron
# 2                     Tickeron
# 3                     Tickeron
# 4                     Tickeron
# 5              Twitter Web App
# 6              Twitter Web App
# 7              Twitter Web App
# 8              Twitter Web App
# 9           Twitter for iPhone
# 10               Investor Feed
# 11               Investor Feed
# 12              Hootsuite Inc.
# 13         Twitter for Android
# 14         Twitter for Android
# 15         Twitter for Android
# 16             Twitter Web App
# 17               Edgar Filings
# 18             Twitter Web App
# 19         Proactive Investors
# 20            SwingTradeBot UK
# 21            SwingTradeBot UK
# 22            SwingTradeBot UK
# 23            SwingTradeBot UK
# 24            Twitter for iPad
# 25                SilentTrades
# 26             Twitter Web App
# 27  DirectorsTalk Auto Posting
# 28             Twitter Web App
# 29          Twitter for iPhone
# 30          Twitter for iPhone
# 31          Twitter for iPhone
# 32        Twitterrific for iOS
# 33          Twitter for iPhone
# 34           www.chartmill.com
# 35           www.chartmill.com
# 36           www.chartmill.com
# 37           www.chartmill.com
# 38           www.chartmill.com
# 39           www.chartmill.com
# 40             Twitter Web App
# 41         Twitter for Android
# 42                     Twitter
# 43                     Twitter
# 44         Twitter for Android
# 45            Twitter for iPad
# 46          Twitter for iPhone
# 47          Twitter for iPhone
# 48          Twitter for iPhone
# 49         Twitter for Android
# 50          Twitter for iPhone
# 51         Twitter for Android
#
#                                                  text        created_at lang  \
# 0   $WPP enters a Downtrend as Momentum Indicator ...  02-09-2022 16:27   en
# 1   $WPP's in Downtrend: Moving Average Convergenc...  01-09-2022 17:41   en
# 2   $WPP's 10-day Moving Average crossed below its...  31-08-2022 01:49   en
# 3   $WPP's 10-day Moving Average broke below its 5...  29-08-2022 17:24   en
# 4   $WPP's 10-day Moving Average crossed below its...  28-08-2022 16:26   en
# 5   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  02-09-2022 01:40   en
# 6   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  31-08-2022 05:45   en
# 7   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  29-08-2022 08:41   en
# 8   💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  27-08-2022 07:11   en
# 9   @GiDavidswright Ay yo las amo, tengo botas y p...  01-09-2022 23:08   es
# 10  $WPP  6-K  WPP   (1 Sep, 9:30am)\n\n📰 Total Vo...  01-09-2022 13:31   en
# 11  $WPP  6-K  WPP   (1 Sep, 6:08am)\n\n📰 Current ...  01-09-2022 10:10   en
# 12  @WPP Acquires Ecommerce Consultancy Newcraft h...  01-09-2022 13:10   en
# 13             @JLD_200 #WPP\nhttps://t.co/cM0OVS2RtT  01-09-2022 12:13  qme
# 14            @JLD_200 #WPP \nhttps://t.co/cM0OVS2RtT  29-08-2022 06:14  qme
# 15      @kucoincom #WPP $WPP\nhttps://t.co/cM0OVRLg5j  27-08-2022 11:59  qme
# 16  #WPP anuncia la adquisición de Newcraft\nhttps...  01-09-2022 10:52   es
# 17  SEC Form 6-K  filed by  $WPP $WPPGF #WPP plc  ...  01-09-2022 10:21   en
# 18  📣 We’re delighted to welcome Newcraft to the W...  01-09-2022 09:58   en
# 19  $WPP WPP to buy European ecommerce consultancy...  01-09-2022 09:56   en
# 20  New 52 Week Low today: #SBRY #RR #BDEV #TW #TP...  01-09-2022 08:34   en
# 21  New 52 Week Low today: #ASTO #BLND #ABDN #WPP ...  31-08-2022 14:48   en
# 22  New 52 Week Low today: #PNN #HWDN #SN #HIK #WP...  30-08-2022 14:53   en
# 23  #WPP technical alerts: New 52 Week Low and New...  27-08-2022 04:02   en
# 24  WPP snaps up Dutch ecommerce firm Newcraft ami...  01-09-2022 08:11   en
# 25  #WPP acquires leading data-first European ecom...  01-09-2022 07:41   en
# 26  Good Morning\n\nUK Newsflow:\n\n#BARC-sells AB...  01-09-2022 06:47   en
# 27  '#WPP acquires leading data-first European eco...  01-09-2022 06:42   en
# 28  238 #RNS in One\n\nTUs 39 incl #AEX #APH #CAM ...  01-09-2022 06:18   en
# 29        @KatiePhang #WPP His new name is John Smith  31-08-2022 16:19   en
# 30                                    @B52Malmet #WPP  30-08-2022 16:49  qme
# 31  #WPP pensando aqui se compro o iPhone 13PM sen...  31-08-2022 16:07   pt
# 32  We can supply high quality, strong &amp; tear ...  31-08-2022 15:18   en
# 33  Agyam eldobom, a miskolci Freiben nem megy a k...  31-08-2022 15:16   hu
# 34  $WPP.L has an average volume of 1535710. This ...  31-08-2022 12:46   en
# 35  $WPP.L has an average volume of 1518070. This ...  30-08-2022 13:37   en
# 36  $WPP.L has an average volume of 1518070. This ...  30-08-2022 03:15   en
# 37  $WPP.L has an average volume of 1518070. This ...  28-08-2022 09:47   en
# 38  $WPP.L has an average volume of 1518070. This ...  27-08-2022 00:22   en
# 39  $WPP.L has an average volume of 1518070. This ...  26-08-2022 20:59   en
# 40  This anti- fossil fuel agency campaign is clea...  30-08-2022 12:38   en
# 41  Gente, já aconteceu com vocês de as datas do w...  30-08-2022 11:11   pt
# 42  #WPP the closest resistance level we identifie...  30-08-2022 02:42   en
# 43  #WPP Regarding indicators, \nhttps://t.co/7aJo...  27-08-2022 09:05   en
# 44                         @StockRocket1 #WPP \n$BOPO  29-08-2022 21:22   pt
# 45  Spojenie #JanBinar &amp; #PetraPipkova tu uz b...  29-08-2022 05:33  und
# 46  WPP Akademi podcast serisi Metaverse&amp;More ...  28-08-2022 18:22   tr
# 47  uma coisa que aprendi nesse tempo sem trabalho...  27-08-2022 18:28   pt
# 48  Não basta nao ter bolo de cenoura. Os caras nã...  27-08-2022 12:27   pt
# 49  A sinking market; #DARK saved me recently, thi...  27-08-2022 08:54   en
# 50               Woohoo! #WPP https://t.co/xU1bnlsvas  27-08-2022 08:53   en
# 51  Hola 👋👋 estamos #SORTEANDO un hermoso Mangrull...  26-08-2022 18:34   es
#
#         geo.place_id  verified         username                     location  \
# 0                NaN     False         Tickeron                Sunnyvale, CA
# 1                NaN     False         Tickeron                Sunnyvale, CA
# 2                NaN     False         Tickeron                Sunnyvale, CA
# 3                NaN     False         Tickeron                Sunnyvale, CA
# 4                NaN     False         Tickeron                Sunnyvale, CA
# 5                NaN     False   SuccessAfter25                          NaN
# 6                NaN     False   SuccessAfter25                          NaN
# 7                NaN     False   SuccessAfter25                          NaN
# 8                NaN     False   SuccessAfter25                          NaN
# 9                NaN     False       lahannadom      Buenos Aires, Argentina
# 10               NaN     False    investor_feed              Toronto, Canada
# 11               NaN     False    investor_feed              Toronto, Canada
# 12               NaN     False    MarTechSeries                Hawthorne, CA
# 13               NaN     False          TZokani                          NaN
# 14               NaN     False          TZokani                          NaN
# 15               NaN     False          TZokani                          NaN
# 16               NaN     False  PdelaPublicidad                Madrid, Spain
# 17               NaN     False     EdgarInsider                          NaN
# 18               NaN      True      WunThompson                       Global
# 19               NaN     False     proactive_UK              London, England
# 20               NaN     False  SwingTradeBotUK              London, England
# 21               NaN     False  SwingTradeBotUK              London, England
# 22               NaN     False  SwingTradeBotUK              London, England
# 23               NaN     False  SwingTradeBotUK              London, England
# 24               NaN     False   andrewsduncan1       London. United Kingdom
# 25               NaN     False    silent_trades                          NaN
# 26               NaN     False      andrewdc208              London, England
# 27               NaN     False    DirectorsTalk                          NaN
# 28               NaN     False   runningprofits               United Kingdom
# 29               NaN     False  JRogers40817410                          NaN
# 30               NaN     False  JRogers40817410                          NaN
# 31               NaN     False        eumexmo99             Campinas, Brasil
# 32               NaN     False     RasheedMemon  Dubai, United Arab Emirates
# 33  07d9f05b02881002     False      gabormatesz             Miskolc, Hungary
# 34               NaN     False        ChartMill                      Belgium
# 35               NaN     False        ChartMill                      Belgium
# 36               NaN     False        ChartMill                      Belgium
# 37               NaN     False        ChartMill                      Belgium
# 38               NaN     False        ChartMill                      Belgium
# 39               NaN     False        ChartMill                      Belgium
# 40               NaN     False  dannyrogers2001              London, England
# 41               NaN     False      itsmoizinho       Campina Grande, Brasil
# 42               NaN     False   stockosaur_com                          NaN
# 43               NaN     False   stockosaur_com                          NaN
# 44               NaN     False        bab_twins                          NaN
# 45               NaN     False     PavolMacinga             Czech & Slovakia
# 46               NaN     False        effectbcw             Istanbul, Turkey
# 47               NaN     False       amandabrbz                     Curitiba
# 48               NaN     False      larigouveia                          NaN
# 49               NaN     False        SandyMidd                   London, UK
# 50               NaN     False    ElvitaNatassa              Bali, Indonesia
# 51               NaN     False     RusticosBell            Moreno, Argentina
#
#                         name
# 0                   Tickeron
# 1                   Tickeron
# 2                   Tickeron
# 3                   Tickeron
# 4                   Tickeron
# 5                Trader PLUS
# 6                Trader PLUS
# 7                Trader PLUS
# 8                Trader PLUS
# 9                       Anto
# 10                Docoh Feed
# 11                Docoh Feed
# 12            MarTech Series
# 13              Tarek Zokani
# 14              Tarek Zokani
# 15              Tarek Zokani
# 16      Periódico PublicidAD
# 17                SEC.report
# 18        Wunderman Thompson
# 19                 Proactive
# 20          SwingTradeBot UK
# 21          SwingTradeBot UK
# 22          SwingTradeBot UK
# 23          SwingTradeBot UK
# 24             Andrew Duncan
# 25         Francis Alexander
# 26               Andrewdc208
# 27             DirectorsTalk
# 28  donncha @ runprofits.com
# 29                  J Rogers
# 30                  J Rogers
# 31       minhapedraamestiça💎
# 32                   𝕽𝖆𝖘𝖍𝖊𝖊𝖉
# 33                     𝙶𝚊𝚋𝚘𝚛
# 34                 ChartMill
# 35                 ChartMill
# 36                 ChartMill
# 37                 ChartMill
# 38                 ChartMill
# 39                 ChartMill
# 40              Danny Rogers
# 41            Its Moizinho 🌻
# 42            stockosaur.com
# 43            stockosaur.com
# 44                 Twins Bab
# 45             Pavol Mačinga
# 46                effect bcw
# 47                    Amanda
# 48                lari ruiva
# 49                     Sandy
# 50          Brown Sugar Bali
# 51            RústicosBell 🤯

# %%
# that's a lot better!
# now let's save our data in pickled format - so that we don't have to grab it again if our machine crashes

import pickle
path = 'twitter' + dt.datetime.now().strftime("%Y-%m-%d_%I-%M-%S_%p") + '.pkl'
df_merged.to_pickle(path)

# %%
# compute a collection of all words from all tweets
# this one takes a min or two to run

words = []
for text in df_merged['text']:
    for word in text.split():
        if word in stopwords.words() or 'http' in word or word == '#WPP':
            continue # skip if word is a link
        else:
            words.append(word)
words
# Out:
# ['$WPP',
#  'enters',
#  'Downtrend',
#  'Momentum',
#  'Indicator',
#  'dropped',
#  '0',
#  'level',
#  'August',
#  '5,',
#  '2022.',
#  'View',
#  'odds',
#  'indicators:',
#  "$WPP's",
#  'Downtrend:',
#  'Moving',
#  'Average',
#  'Convergence',
#  'Divergence',
#  '(MACD)',
#  'Histogram',
#  'turned',
#  'negative.',
#  'View',
#  'odds',
#  'indicators:',
#  "$WPP's",
#  '10-day',
#  'Moving',
#  'Average',
#  'crossed',
#  '50-day',
#  'Moving',
#  'Average',
#  'August',
#  '16,',
#  '2022.',
#  'View',
#  'odds',
#  'indicators:',
#  "$WPP's",
#  '10-day',
#  'Moving',
#  'Average',
#  'broke',
#  '50-day',
#  'Moving',
#  'Average',
#  'August',
#  '16,',
#  '2022.',
#  'View',
#  'odds',
#  'indicators:',
#  "$WPP's",
#  '10-day',
#  'Moving',
#  'Average',
#  'crossed',
#  '50-day',
#  'Moving',
#  'Average',
#  'August',
#  '16,',
#  '2022.',
#  'View',
#  'odds',
#  'indicators:',
#  '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats',
#  'Team',
#  'members',
#  'making',
#  'huge',
#  'gains',
#  'Trade',
#  'Ideas',
#  '$WPP',
#  '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats',
#  'Team',
#  'members',
#  'making',
#  'huge',
#  'gains',
#  'Trade',
#  'Ideas',
#  '$WPP',
#  '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats',
#  'Team',
#  'members',
#  'making',
#  'huge',
#  'gains',
#  'Trade',
#  'Ideas',
#  '$WPP',
#  '💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats',
#  'Team',
#  'members',
#  'making',
#  'huge',
#  'gains',
#  'Trade',
#  'Ideas',
#  '$WPP',
#  '@GiDavidswright',
#  'Ay',
#  'amo,',
#  'botas',
#  'pilotos',
#  'viví',
#  '🇬🇧',
#  'odio',
#  'usarlas',
#  'acá',
#  '😒',
#  '#wpp',
#  'año.',
#  'Ya',
#  'sé',
#  '$WPP',
#  '6-K',
#  'WPP',
#  '(1',
#  'Sep,',
#  '9:30am)',
#  '📰',
#  'Total',
#  'Voting',
#  'Rights',
#  'Capital',
#  '#6K',
#  '#News',
#  '$WPP',
#  '6-K',
#  'WPP',
#  '(1',
#  'Sep,',
#  '6:08am)',
#  '📰',
#  'Current',
#  'report',
#  '(foreign)',
#  '#6K',
#  '#News',
#  '@WPP',
#  'Acquires',
#  'Ecommerce',
#  'Consultancy',
#  'Newcraft',
#  '#martech',
#  '#marketing',
#  '#Technology',
#  '#ecommerce',
#  '@JLD_200',
#  '@JLD_200',
#  '@kucoincom',
#  '$WPP',
#  'anuncia',
#  'adquisición',
#  'Newcraft',
#  'SEC',
#  'Form',
#  '6-K',
#  'filed',
#  '$WPP',
#  '$WPPGF',
#  'plc',
#  '📣',
#  'We’re',
#  'delighted',
#  'welcome',
#  'Newcraft',
#  'WT',
#  'family!',
#  '.',
#  'Find',
#  '🔗:',
#  '.',
#  '#WunThompson',
#  '#NEWCRAFT',
#  '$WPP',
#  'WPP',
#  'buy',
#  'European',
#  'ecommerce',
#  'consultancy',
#  'Newcraft',
#  'undisclosed',
#  'sum',
#  'New',
#  '52',
#  'Week',
#  'Low',
#  'today:',
#  '#SBRY',
#  '#RR',
#  '#BDEV',
#  '#TW',
#  '#TPK',
#  '#LAND',
#  '#BLND',
#  '#GSK',
#  '#LMP',
#  '#SSPG',
#  '#SVS',
#  '#DLN',
#  '#PAGE',
#  '#DCC',
#  '#SGRO',
#  '...',
#  'New',
#  '52',
#  'Week',
#  'Low',
#  'today:',
#  '#ASTO',
#  '#BLND',
#  '#ABDN',
#  '#BBOX',
#  '...',
#  'New',
#  '52',
#  'Week',
#  'Low',
#  'today:',
#  '#PNN',
#  '#HWDN',
#  '#SN',
#  '#HIK',
#  '...',
#  'technical',
#  'alerts:',
#  'New',
#  '52',
#  'Week',
#  'Low',
#  'New',
#  '52',
#  'Week',
#  'Closing',
#  'Low',
#  'WPP',
#  'snaps',
#  'Dutch',
#  'ecommerce',
#  'firm',
#  'Newcraft',
#  'amid',
#  'buoyant',
#  'sales.',
#  '#advertising',
#  'acquires',
#  'leading',
#  'data-first',
#  'European',
#  'ecommerce',
#  'consultancy',
#  'Newcraft',
#  '-',
#  '-',
#  '#Communications',
#  '#Advertising',
#  '#PublicRelations',
#  '#Technology',
#  '#eCommerce',
#  '#Newcraft',
#  '#FTSE100',
#  'Good',
#  'Morning',
#  'UK',
#  'Newsflow:',
#  '#BARC-sells',
#  'ABSA',
#  'stake',
#  '£538m',
#  '#CAM-Warning',
#  '#CBOX-CEO',
#  'buys',
#  'shs',
#  'fall',
#  '#GKP-Production',
#  'guide',
#  'reiterated',
#  '#IXI-Exceeds',
#  'previous',
#  'guidance',
#  '#JSG-Inline',
#  '#KNOS-Inline',
#  '#RIO-Buying',
#  'rest',
#  'Turquoise',
#  'Hill',
#  '$3.3b',
#  '#WPP-Acquisition',
#  "'#WPP",
#  'acquires',
#  'leading',
#  'data-first',
#  'European',
#  'ecommerce',
#  'consultancy',
#  "Newcraft'",
#  'Link:',
#  '#Communications',
#  '#Advertising',
#  '#PublicRelations',
#  '#Technology',
#  '#eCommerce',
#  '#Newcraft',
#  '#FTSE100',
#  '#Investing',
#  '238',
#  '#RNS',
#  'One',
#  'TUs',
#  '39',
#  'incl',
#  '#AEX',
#  '#APH',
#  '#CAM',
#  '#EQT',
#  '#GEMD',
#  '#GKP',
#  '#IXI',
#  '#JSG',
#  '#KNOS',
#  '#LOOP',
#  '#MXC',
#  '#NTOG',
#  '#PPH',
#  '#SIHL',
#  '#SPO',
#  '#STM',
#  '#WDS',
#  '#ZAIM',
#  'Contract',
#  'Wins:',
#  '#LOOP',
#  '#COG',
#  '#ORCP',
#  '#SWG',
#  'M&amp;A:',
#  '#ALBA',
#  '#AWE',
#  '#BRH',
#  '#RBD',
#  '#SRP',
#  'Bullish/Bearish',
#  'Plot👇',
#  'R/T',
#  '&amp;',
#  'share',
#  '🙏',
#  '@KatiePhang',
#  'His',
#  'John',
#  'Smith',
#  '@B52Malmet',
#  'pensando',
#  'aqui',
#  'compro',
#  'iPhone',
#  '13PM',
#  'sendo',
#  'msm',
#  'coisa',
#  'queria',
#  '☹️',
#  'We',
#  'supply',
#  'high',
#  'quality,',
#  'strong',
#  '&amp;',
#  'tear',
#  'resistant',
#  '#Woven',
#  '#Polypropylene',
#  '(#WPP)',
#  'Bags,',
#  'Coated',
#  '#CementSacks',
#  '&amp;',
#  'Liners.',
#  'Our',
#  'bags',
#  'satisfactorily',
#  'sectors',
#  '#Fertilizers,',
#  '#Chemicals,',
#  '#Cement,',
#  '#Sugar,',
#  '#Textile',
#  '#PPBags',
#  '#WPPBags',
#  'Agyam',
#  'eldobom,',
#  'miskolci',
#  'Freiben',
#  'megy',
#  'klíma.',
#  'Rezsit',
#  'élményt',
#  'csökkentenek.',
#  '😕☕️👎🏼',
#  '#wpp',
#  '#freicafe',
#  '$WPP.L',
#  'average',
#  'volume',
#  '1535710.',
#  'This',
#  'sign',
#  'nice',
#  'liquid',
#  'stock.',
#  '#ChartMill',
#  '#WPPPLC',
#  '#LondonStockExchange',
#  '#TechnicalAnalysis',
#  '$WPP.L',
#  'average',
#  'volume',
#  '1518070.',
#  'This',
#  'sign',
#  'nice',
#  'liquid',
#  'stock.',
#  '#ChartMill',
#  '#WPPPLC',
#  '#LondonStockExchange',
#  '#TechnicalAnalysis',
#  '$WPP.L',
#  'average',
#  'volume',
#  '1518070.',
#  'This',
#  'sign',
#  'nice',
#  'liquid',
#  'stock.',
#  '#ChartMill',
#  '#WPPPLC',
#  '#LondonStockExchange',
#  '#TechnicalAnalysis',
#  '$WPP.L',
#  'average',
#  'volume',
#  '1518070.',
#  'This',
#  'sign',
#  'nice',
#  'liquid',
#  'stock.',
#  '#ChartMill',
#  '#WPPPLC',
#  '#LondonStockExchange',
#  '#TechnicalAnalysis',
#  '$WPP.L',
#  'average',
#  'volume',
#  '1518070.',
#  'This',
#  'sign',
#  'nice',
#  'liquid',
#  'stock.',
#  '#ChartMill',
#  '#WPPPLC',
#  '#LondonStockExchange',
#  '#TechnicalAnalysis',
#  '$WPP.L',
#  'average',
#  'volume',
#  '1518070.',
#  'This',
#  'sign',
#  'nice',
#  'liquid',
#  'stock.',
#  '#ChartMill',
#  '#WPPPLC',
#  '#LondonStockExchange',
#  '#TechnicalAnalysis',
#  'This',
#  'anti-',
#  'fossil',
#  'fuel',
#  'agency',
#  'campaign',
#  'away...',
#  '#edelman',
#  '#wpp',
#  '#shell',
#  '#bp',
#  '@prweek',
#  'Gente,',
#  'aconteceu',
#  'datas',
#  'wpp',
#  'estarem',
#  'erradas?',
#  'Algumas',
#  'conversas',
#  'aconteceram',
#  'data',
#  'outro',
#  'dia?',
#  'Ou',
#  'fotos',
#  'aparecendo',
#  'conversas',
#  'aleatórias',
#  'bug?',
#  '#wpp',
#  '#bug',
#  '#VMAs',
#  '#HouseoftheDragon',
#  '#studytwt',
#  'closest',
#  'resistance',
#  'level',
#  'identified',
#  '$45.01',
#  'Try',
#  'intuitive',
#  'free',
#  'stock',
#  'screener',
#  '-',
#  'screener',
#  'made',
#  'Regarding',
#  'indicators,',
#  '@StockRocket1',
#  '$BOPO',
#  'Spojenie',
#  '#JanBinar',
#  '&amp;',
#  '#PetraPipkova',
#  'uz',
#  'historicky',
#  'fungovalo',
#  'napriek',
#  'prepojeniu',
#  '#IPG',
#  '#WPP…',
#  'interne',
#  'zaclenenie,',
#  'ktore',
#  '@hondzyk76',
#  'realizuje',
#  'uspesne',
#  'McCann',
#  'Prague',
#  'uz',
#  'roky,',
#  'vyrazny',
#  'krok',
#  'pozitivna',
#  'cesta.',
#  '#McCannMedia',
#  'WPP',
#  'Akademi',
#  'podcast',
#  'serisi',
#  'Metaverse&amp;More',
#  'pilot',
#  'bölümleri',
#  'yayına',
#  'başladı!',
#  'Web',
#  '3.0,',
#  'NFT,',
#  'Blockchain',
#  'konu',
#  'başlıkları',
#  'kanaat',
#  'lideri',
#  'konukların',
#  'katılımı',
#  'evrenler',
#  'arası',
#  'bilgi',
#  'akışına',
#  'dönüşüyor.',
#  '#WPPAcademies',
#  '#MetaVerse',
#  'coisa',
#  'aprendi',
#  'nesse',
#  'tempo',
#  'trabalho',
#  'dá',
#  'pra',
#  'esperar',
#  'tempo',
#  'certo',
#  'pra',
#  'comprar',
#  'coisas',
#  'tá',
#  'precisando',
#  'fica',
#  'postergando',
#  'motivo',
#  'gastando',
#  'coisas',
#  'inúteis',
#  'invés',
#  'comprar',
#  'precisa',
#  '#wpp',
#  'Não',
#  'basta',
#  'nao',
#  'cenoura.',
#  'Os',
#  'caras',
#  'calda',
#  'chocolate',
#  'chocolate.',
#  'QUE',
#  'MUNDO',
#  'É',
#  'ESSE',
#  'A',
#  'sinking',
#  'market;',
#  '#DARK',
#  'saved',
#  'recently,',
#  'week',
#  '#MCRO',
#  'bid',
#  '+94%',
#  'Friday',
#  'rescue,',
#  'market',
#  'pricing',
#  'bid.',
#  'O&amp;G',
#  'supports,',
#  'big',
#  'fallers',
#  'inc;',
#  '#WPP,',
#  '#HIK,',
#  '#REDD,',
#  '#LGEN',
#  '&amp;',
#  '#GSK.',
#  'FY',
#  'revenue',
#  '+69%',
#  '#S32',
#  'returns',
#  '10%',
#  'mkt',
#  'cap',
#  'year.',
#  'Folio',
#  'week',
#  '-1.4%,',
#  'YTD',
#  '-2.3%',
#  'Woohoo!',
#  'Hola',
#  '👋👋',
#  '#SORTEANDO',
#  'hermoso',
#  'Mangrullo',
#  'RústicosBell',
#  '🤯',
#  'Se',
#  'viene',
#  'verano',
#  ',ideal',
#  'regalo',
#  'niños',
#  '🌞🎉',
#  'Prova',
#  'suerte',
#  'RústicosBell',
#  '😁',
#  'Empresa',
#  'Familiar',
#  'dedicada',
#  'Rústico',
#  '💓',
#  '#wpp-#catalogo',
#  '1125036665!',
#  'Números',
#  'Disponibles!',
#  'Solo',
#  'Bs',
#  'As.']

# %%
# let's find the most frequent words in these tweets

from collections import Counter

c = Counter(words)
print(c.most_common()[:10])  # top 10
# Out:
# [('$WPP', 10), ('Moving', 7), ('Average', 7), ('This', 7), ('Newcraft', 6), ('$WPP.L', 6), ('average', 6), ('volume', 6), ('sign', 6), ('nice', 6)]

# %%
from prettytable import PrettyTable

pt = PrettyTable(field_names=['Word', 'Count']) 
c = Counter(words)
[ pt.add_row(kv) for kv in c.most_common()[:10] ]
pt.align['Word'], pt.align['Count'] = 'l', 'r' # Set column alignment
print(pt)
# Out:
# +----------+-------+
# | Word     | Count |
# +----------+-------+
# | $WPP     |    10 |
# | Moving   |     7 |
# | Average  |     7 |
# | This     |     7 |
# | Newcraft |     6 |
# | $WPP.L   |     6 |
# | average  |     6 |
# | volume   |     6 |
# | sign     |     6 |
# | nice     |     6 |
# +----------+-------+
